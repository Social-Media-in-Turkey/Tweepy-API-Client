# %% [markdown]
# # A comprehensive guide for using the Twitter API v2 with Tweepy in Python
#
# **Guide:** https://dev.to/twitterdev/a-comprehensive-guide-for-using-the-twitter-api-v2-using-tweepy-in-python-15d9
#
# **Sections**:
# 1. Searching for Tweets from the last 7 days
# 2. Searching for Tweets from the full-archive of public Tweets (available in **Academic Research Product Track**)
# 3. Getting Tweets from the full-archive of public Tweets for a specific time-frame (available in **Academic Research Product Track**)
# 4. Getting more than 100 Tweets at a time using paginator
# 5. Writing Tweets to a text file
# 6. Getting Tweets with user information, for each Tweet
# 7. Getting Tweets with media information, for each Tweet
# 8. Searching for geo-tagged Tweets (available in **Academic Research Product Track**)
# 9. Getting Tweet counts (volume) for a search query
# 10. Getting a user's timeline
# 11. Getting a user's mentions
# 12. Getting a user's followers
# 13. Getting users that a user follows
# 14. Getting users that like a Tweet
# 15. Getting users that retweeted a Tweet
# 16. Getting Tweets that a user liked
# 17. Lookup Tweets using Tweet IDs
# 18. Lookup Users using User IDs

# %% [markdown]
# ## Prerequisite

# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\melihcanyardi\anaconda3\lib\site-packages (4.1.0)
# Requirement already satisfied: requests<3,>=2.11.1 in c:\users\melihcanyardi\anaconda3\lib\site-packages (from tweepy) (2.25.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.0.0 in c:\users\melihcanyardi\anaconda3\lib\site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\melihcanyardi\anaconda3\lib\site-packages (from requests<3,>=2.11.1->tweepy) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\melihcanyardi\anaconda3\lib\site-packages (from requests<3,>=2.11.1->tweepy) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\melihcanyardi\anaconda3\lib\site-packages (from requests<3,>=2.11.1->tweepy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\melihcanyardi\anaconda3\lib\site-packages (from requests<3,>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\melihcanyardi\anaconda3\lib\site-packages (from requests-oauthlib<2,>=1.0.0->tweepy) (3.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tweepy
import json

# %%
tweepy.__version__
# Out:
# '4.1.0'

# %%
with open('Twitter_API_keys_melihcanyardi.json', 'r') as f:
    keys_tokens = json.load(f)
    
bearer_token = keys_tokens['bearer_token']

# %%
client = tweepy.Client(bearer_token=bearer_token)

# %% [markdown]
# ## 1. Searching for Tweets from the last 7 days
#
#
# - You have to pass a search query to `search_recent_tweets` --> [Search queries](https://github.com/twitterdev/getting-started-with-the-twitter-api-v2-for-academic-research/blob/main/modules/5-how-to-write-search-queries.md)
#
# - Default: Tweet ID & Tweet Text, 10 Tweets.
#     - If you need additional Tweet fields such as [context_annotations](https://developer.twitter.com/en/docs/twitter-api/annotations/overview), created_at (the time the tweet was created) etc., you can specifiy those fields using the `tweet_fields` parameter, as shown in the example below. --> [Available fields](https://developer.twitter.com/en/docs/twitter-api/fields)
#     - If you want more than 10 Tweets per request, you can specify that using the `max_results` parameter. The maximum Tweets per request is 100.
# - Python code example:
#
# ```python
# # Replace with your own search query
# query = 'from:suhemparack -is:retweet'
#
# tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)
#
# for tweet in tweets.data:
#     print(tweet.text)
#     if len(tweet.context_annotations) > 0:
#         print(tweet.context_annotations)
# ```

# %%
# Example: Give me all Tweets that contain the word dolar that are in Turkish
query = 'dolar lang:tr'

tweets = client.search_recent_tweets(query=query)

for tweet in tweets.data:
    print(tweet.text)
# Out:
# ABD istihdam verileri ateş etti...
#
# Dolar endeksine güvenenler burada mı 😎
# 🇺🇸 ABD, Tarım Dışı İstihdam (Eki) Verisi!
#
# 👉 312K olan veri,
#
# 🔴 531K olarak açıklandı.
#
# 🌐 Fırsatlardan şimdi yararlanın; https://t.co/irCpgLoE4v
#
# #abd #dolar #altın #cuma https://t.co/6wujGf956c
# RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :)
# RT @Matsuda_Rem: $Roco Yüzde 39 Apr oranıyla dolaşımdaki arzın yüzde 50 si stake edilmiş durumda şuan. Topluluğun ekibe ve çalışmalarına ne…
# RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :)
# RT @Kervan_Reisen: Everest’e tırmanırken fenalaşan Merve Bakdur, Katmandu'da gözünü açtığında helikopter masrafı olarak 7️⃣5️⃣0️⃣0️⃣ 💵 dola…
# RT @ilhan_karasu: 1 milyar dolar #tether basım zamanlarını hatırlıyorum 100k habercisi .
# 🇺🇸 ABD Tarım Dışı İstihdam (Ekim)
#
# Açıklanan: 531K
# Beklenti: 450K
# Önceki: 312K
#
# #dolar https://t.co/5CzimuUXgF
# 🇺🇸 ABD Tarım Dışı İstihdam (Ekim)
#
# #dolar #eurusd https://t.co/qWeBdQF8oO
# 🇬🇧 ABD - Tarım Dışı İstihdam (Eki) Verileri Açıklandı!
#
# 🟩Önceki: 312K
#
# ✴️Açıklanan: 531K
#
# 🌐Dünya piyasalarında Lotas Capital ile yer edinin!
#
# 🔐LOTAS CAPITAL
#
# #USDT #usdtry  #dolar  #CUMA https://t.co/DbccB6SAWR

# %%
# Example: Give me all Tweets from the MagicRealismBot account
query = 'from:MagicRealismBot'

tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=20)

for i, tweet in enumerate(tweets.data):
    print(f"{i+1}- {tweet.text}")
    if tweet.context_annotations:
        print(f"***Context annotations for {i+1}: {tweet.context_annotations}")
# Out:
# 1- A rainbow made of the patriarchy appears in London.
# 2- A Scottish child hears of a library located inside an opal, and dedicates her life to finding it.
# 3- A math teacher makes love to an orangutan inside a porcelain gold mine.
# 4- A Caribbean attorney sets up a law firm that gives advice to 16-year-old poltergeists.
# 5- An English maharajah makes a speech about beehives that lasts for 62 million years.
# 6- An ambitious drag queen owns a crystal ball which lets her see every tennis racquet on earth.
# 7- A politician prepares a turducken made of a sea serpent, inside a leopard, inside a salamander.
# 8- An evil Sicilian architect finds a tiny crystal that gives her complete understanding of the class struggle.
# 9- A Mexican archangel photographs the stock exchange.
# 10- An archduke is writing a list of people he plans to kill: A solicitor, an anaesthetist and an undertaker.
# 11- A university professor regurgitates rainbows.
# 12- A congressman searches for a map which shows the location of every rollercoaster in Montréal.
# 13- A queen is found dead in a shopping mall. Beside the body is a heart and a puddle of milk. Can you explain what happened?
# ***Context annotations for 13: [{'domain': {'id': '65', 'name': 'Interests and Hobbies Vertical', 'description': 'Top level interests and hobbies groupings, like Food or Travel'}, 'entity': {'id': '825047692124442624', 'name': 'Food', 'description': 'Food'}}, {'domain': {'id': '65', 'name': 'Interests and Hobbies Vertical', 'description': 'Top level interests and hobbies groupings, like Food or Travel'}, 'entity': {'id': '834828264786898945', 'name': 'Drinks', 'description': 'Drinks'}}, {'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '834828445238431744', 'name': 'Generic Drinks', 'description': 'Generic Drinks'}}, {'domain': {'id': '67', 'name': 'Interests and Hobbies', 'description': 'Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks'}, 'entity': {'id': '850419241790472192', 'name': 'Milk', 'description': 'Milk'}}]
# 14- A baron buys a magnetic device which allows him to destroy pain.
# 15- A Madagascan princess wakes at midnight every night to have sexual intercourse with molecular gastronomy.
# ***Context annotations for 15: [{'domain': {'id': '30', 'name': 'Entities [Entity Service]', 'description': 'Entity Service top level domain, every item that is in Entity Service should be in this domain'}, 'entity': {'id': '1358715418622402560', 'name': 'Food science'}}]
# 16- A Tamil queen passes a law that everyone must be made of climate change.
# 17- A president owns a mirror that allows him to taste every dish in Glasgow at the same time.
# 18- An undertaker from Baltimore begs a genie to help her destroy the Moon.
# 19- There is a gay sauna in Bangkok. Everyone who goes there is a swimming pool.
# ***Context annotations for 19: [{'domain': {'id': '66', 'name': 'Interests and Hobbies Category', 'description': 'A grouping of interests and hobbies entities, like Novelty Food or Destinations'}, 'entity': {'id': '1364594897458663425', 'name': 'Sauna'}}]
# 20- A hairdresser in Khartoum is famous for taking a photograph of Half-Life 3.

# %% [markdown]
# ## 2. Searching for Tweets from the full-archive of public Tweets
#
# - **NOTE:** This feature is available in **academic research product track**!!!
# - Access tweets older than 7 days i.e. from the full archive of publicly available Tweets by passing your search query to `search_all_tweets`. You can also specify additional Tweet fields etc. as in the example above.
# - Python code example:
#
# ```python
# client = tweepy.Client(bearer_token='REPLACE_ME')
#
# # Replace with your own search query
# query = 'from:suhemparack -is:retweet'
#
# tweets = client.search_all_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100)
#
# for tweet in tweets.data:
#     print(tweet.text)
#     if len(tweet.context_annotations) > 0:
#         print(tweet.context_annotations)
# ```

# %% [markdown]
# ## 3. Getting Tweets from the full-archive of public Tweets for a specific time-frame
#
# - **NOTE:** This feature is available in **academic research product track**!!!
# - If you want to get Tweets from the full-archive for a specific time-period, you can specify the time-period using the `start_time` and `end_time` parameters.
# - Python code example:
#
# ```python
# client = tweepy.Client(bearer_token='REPLACE_ME')
#
# # Replace with your own search query
# query = 'from:suhemparack -is:retweet'
#
# # Replace with time period of your choice
# start_time = '2020-01-01T00:00:00Z'
#
# # Replace with time period of your choice
# end_time = '2020-08-01T00:00:00Z'
#
# tweets = client.search_all_tweets(query=query, tweet_fields=['context_annotations', 'created_at'],
#                                   start_time=start_time,
#                                   end_time=end_time, max_results=100)
#
# for tweet in tweets.data:
#     print(tweet.text)
#     print(tweet.created_at)
# ```

# %% [markdown]
# ## 4. Getting more than 100 Tweets at a time using paginator
#
# - If you need more than 100 Tweets, you will have to use the [paginator](https://docs.tweepy.org/en/latest/pagination.html) and specify the limit i.e. the total number of Tweets that you want.
# - Python code example:
#
# ```python
# client = tweepy.Client(bearer_token='REPLACE_ME')
#
# # Replace with your own search query
# query = 'covid -is:retweet'
#
# # Replace the limit=1000 with the maximum number of Tweets you want
# for tweet in tweepy.Paginator(client.search_recent_tweets, query=query,
#                               tweet_fields=['context_annotations', 'created_at'], max_results=100).flatten(limit=1000):
#     print(tweet.id)
# ```

# %%
client = tweepy.Client(bearer_token=bearer_token)

query = 'dolar lang:tr'

for tweet in tweepy.Paginator(client.search_recent_tweets, query=query,
                              tweet_fields=['created_at'], max_results=100).flatten(limit=500):
    print(f"Tweet ID: {tweet.id}\nText: {tweet.text},\nCreated at: {tweet.created_at}\n\n")
# Out:
# Tweet ID: 1456600041481723914
# Text: RT @sagdanhaber: Everest’e tırmanırken fenalaşan Merve Bakdur, Katmandu'da gözünü açtığında helikopter masrafı olarak 7 bin 500 dolar borçl…,
# Created at: 2021-11-05 12:31:26+00:00
#
#
# Tweet ID: 1456600031008546817
# Text: ABD istihdam verileri ateş etti...
#
# Dolar endeksine güvenenler burada mı 😎,
# Created at: 2021-11-05 12:31:24+00:00
#
#
# Tweet ID: 1456599993897394188
# Text: 🇺🇸 ABD, Tarım Dışı İstihdam (Eki) Verisi!
#
# 👉 312K olan veri,
#
# 🔴 531K olarak açıklandı.
#
# 🌐 Fırsatlardan şimdi yararlanın; https://t.co/irCpgLoE4v
#
# #abd #dolar #altın #cuma https://t.co/6wujGf956c,
# Created at: 2021-11-05 12:31:15+00:00
#
#
# Tweet ID: 1456599990797799426
# Text: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :),
# Created at: 2021-11-05 12:31:14+00:00
#
#
# Tweet ID: 1456599987656220676
# Text: RT @Matsuda_Rem: $Roco Yüzde 39 Apr oranıyla dolaşımdaki arzın yüzde 50 si stake edilmiş durumda şuan. Topluluğun ekibe ve çalışmalarına ne…,
# Created at: 2021-11-05 12:31:14+00:00
#
#
# Tweet ID: 1456599986129547270
# Text: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :),
# Created at: 2021-11-05 12:31:13+00:00
#
#
# Tweet ID: 1456599973500440581
# Text: RT @Kervan_Reisen: Everest’e tırmanırken fenalaşan Merve Bakdur, Katmandu'da gözünü açtığında helikopter masrafı olarak 7️⃣5️⃣0️⃣0️⃣ 💵 dola…,
# Created at: 2021-11-05 12:31:10+00:00
#
#
# Tweet ID: 1456599971399016453
# Text: RT @ilhan_karasu: 1 milyar dolar #tether basım zamanlarını hatırlıyorum 100k habercisi .,
# Created at: 2021-11-05 12:31:10+00:00
#
#
# Tweet ID: 1456599962951852034
# Text: 🇺🇸 ABD Tarım Dışı İstihdam (Ekim)
#
# Açıklanan: 531K
# Beklenti: 450K
# Önceki: 312K
#
# #dolar https://t.co/5CzimuUXgF,
# Created at: 2021-11-05 12:31:08+00:00
#
#
# Tweet ID: 1456599958581391367
# Text: 🇺🇸 ABD Tarım Dışı İstihdam (Ekim)
#
# #dolar #eurusd https://t.co/qWeBdQF8oO,
# Created at: 2021-11-05 12:31:07+00:00
#
#
# Tweet ID: 1456599952038236173
# Text: 🇬🇧 ABD - Tarım Dışı İstihdam (Eki) Verileri Açıklandı!
#
# 🟩Önceki: 312K
#
# ✴️Açıklanan: 531K
#
# 🌐Dünya piyasalarında Lotas Capital ile yer edinin!
#
# 🔐LOTAS CAPITAL
#
# #USDT #usdtry  #dolar  #CUMA https://t.co/DbccB6SAWR,
# Created at: 2021-11-05 12:31:05+00:00
#
#
# Tweet ID: 1456599950129831946
# Text: Ben buradan bir miktar kâr realize ettim. 57 dolar bölgesi oldukça önemli bir direnç. https://t.co/AGKrPdGfy1,
# Created at: 2021-11-05 12:31:05+00:00
#
#
# Tweet ID: 1456599932345987078
# Text: ABD İklim Özel Temsilcisi Kerry: Gelişmekte olan ülkelere yıllık 100 milyar dolar fon hedefine 2022'de ulaşabiliriz - BBC News Türkçe https://t.co/AVaZNE7pRv,
# Created at: 2021-11-05 12:31:00+00:00
#
#
# Tweet ID: 1456599891631878144
# Text: RT @RtradeCn: Bu hafta da 100 dolar verelim takipçilerimize.💵
# Hemen hemen her hafta yaparız demiştik🧿
# RT ve Beğeni yapanlardan 2 kişiye ben…,
# Created at: 2021-11-05 12:30:51+00:00
#
#
# Tweet ID: 1456599881607430146
# Text: @gszinciri Fotografdakinden daha rahat pozisyondu onu soyliim bi kere. Topa bas sola ver bu kadar. Maalesef Momo bunu bile dusunemeyecek kafada bir futbolcu. Momo-dan bize forvet falan olmaz. Evet belirlo yetenekleri var ama 4 milyon dolar verilmez,
# Created at: 2021-11-05 12:30:48+00:00
#
#
# Tweet ID: 1456599868366016519
# Text: RT @tolgaozcelkk909: SKANDAL!!!
#  Pfizer'den Çocuklarda Aşılanmayı Teşvik Eden Doktora 2 Milyon Dolar Ödendi!
# https://t.co/aDqnUL5rD3,
# Created at: 2021-11-05 12:30:45+00:00
#
#
# Tweet ID: 1456599847570706439
# Text: Dolar uzerinden memlekette aclik ve sefalet var diyen Muhalefetin sozde Milliyetci ve Ulusalcilari Basak Hanimi duydunuz mu ?
#
# “Kocasi olan Teror destekcisi  Selahattin hapse atildiginda dolar 3    Bugun 9.7 mis !!!
#
# @hdpdemirtas
# @meral_aksener
# @kilicdarogluk https://t.co/pMkC3IX5ts,
# Created at: 2021-11-05 12:30:40+00:00
#
#
# Tweet ID: 1456599843183472644
# Text: RT @VatandasTube: İki vatandaş arasında 128 milyar dolar tartışması üzerinden yumruk yumruğa kavga çıktı. Via/@Zeyrek_00
# #BirŞeylerOlduGerç…,
# Created at: 2021-11-05 12:30:39+00:00
#
#
# Tweet ID: 1456599839228190720
# Text: River Plate'in Adidas ile sponsorluk sözleşmesi.
# 6 yılda 31 milyon dolar garanti edilmiş(9,1'i peşin).
# Libertadores şampiyonluğu'nun 1m $, Lig şampiyonluğunun 0,75m $, Sudamericana şampiyonluğunun 0,5m $, Arjantin Kupası'nın 0,2m $  bonusu var.
# Satışlardan da tutara göre pay var. https://t.co/9fTyfn2Lvl,
# Created at: 2021-11-05 12:30:38+00:00
#
#
# Tweet ID: 1456599830688583681
# Text: 🇺🇸 AMERİKA - Tarım Dışı İstihdam (Eki)
#
# #PMI #ISM #ekonomiktakvim #forexsignals #forextrader #forextrading #forexmarket #forexlifestyle #FOREXTECHT #forexsignal #dolar #usdtry #GBPJPY #GBP #USDCAD #truvafx https://t.co/Y3uSGvmcGu,
# Created at: 2021-11-05 12:30:36+00:00
#
#
# Tweet ID: 1456599826917900290
# Text: RT @murselkanatoglu: Küreselciler de çok iyi biliyor ki Türkiye'de kendilerine kök söktüren kişi Berat Albayrak'tır
# Ülke'nin parasını gizli…,
# Created at: 2021-11-05 12:30:35+00:00
#
#
# Tweet ID: 1456599809104699398
# Text: @abdullahciftcib Anlamı yeniden tedbir. Zaten kırılmış tedarik zincirini iyice parçalamak. Şu anda Temel gıda stoklamak dolar, altın stoklamaktan daha iyi. Bunu hane bazında değil devlet olarak yapmalıyız.,
# Created at: 2021-11-05 12:30:31+00:00
#
#
# Tweet ID: 1456599805854109698
# Text: RT @RefahHilvan: Maliye Bakanı "Doğalgazı 100'e alıp vatandaşa 25 birime satıyoruz" demiş büyük bir jestmiş gibi.
# Eğer TL bu kadar değer k…,
# Created at: 2021-11-05 12:30:30+00:00
#
#
# Tweet ID: 1456599802649759749
# Text: RT @borsaparatic: Binance'dan USDT lerinizi dışarı çıkarıp gerçek dolar yaparken minimum efor ve sıfır kayıpla nasıl yapacağınızı anlatacağ…,
# Created at: 2021-11-05 12:30:29+00:00
#
#
# Tweet ID: 1456599793619374082
# Text: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :),
# Created at: 2021-11-05 12:30:27+00:00
#
#
# Tweet ID: 1456599783175606278
# Text: ABD hazinesinin Ekim 2020’de ihrac ettigi 100 dolarlik bono/tahvil’in bugunku reel degeri 95 dolar.
#
# Diger gelismis ulkelerde de durum ayni.
#
# Diger yandan kamu borcu/gdp tarihi yuksek seviyelerde.
#
# Fed’in yakin donemde enflasyonla mucadele edecegini saniyorsaniz, bol sanslar. https://t.co/epPQHhZ8YL,
# Created at: 2021-11-05 12:30:25+00:00
#
#
# Tweet ID: 1456599771880247301
# Text: Kripto fenomenleri takip edin ama asla onlarla birlikte işleme girmeyin. Asla "araştırdım beğendim" tarzında reklam aldığını belirtmeden reklam yapanlara 100 dolar daha çok kazanmak için sizinle oynayanlara prim vermeyin. Neredeyse hiçbiri sandığınız gibi para ile oynamıyor.,
# Created at: 2021-11-05 12:30:22+00:00
#
#
# Tweet ID: 1456599763781029896
# Text: RT @yillar_kayip: Emniyet müdürü bir arkadaş vardı eşi parasızlıktan dolayı 5 ayda bir geliyordu.😔 garibim içine ata ata midesi bitmişti  n…,
# Created at: 2021-11-05 12:30:20+00:00
#
#
# Tweet ID: 1456599750787145739
# Text: @GolgeSessiz #BizeALLAHyeter ne ekonomi ne dolar umurumuzda değil. Elhamdülillah. Maşallah hak yolu,
# Created at: 2021-11-05 12:30:17+00:00
#
#
# Tweet ID: 1456599726015631361
# Text: RT @sefikdiyin: Bu saatten sonra beni mutlu edebilecek tek şey; benden habersiz hesabıma yatırılan 2 milyon dolar,
# Created at: 2021-11-05 12:30:11+00:00
#
#
# Tweet ID: 1456599721145942016
# Text: RT @Seyfett39479898: Başkanlık sistemi gelirse,
# Türkiye uçacak dediler,
# Evet,türkiye uçtu,
# Ama zenginliğe deyil,yoksulluga  uçtu.
#
# Hak,adal…,
# Created at: 2021-11-05 12:30:10+00:00
#
#
# Tweet ID: 1456599712614727684
# Text: 15:30⏱
# 𝑫𝒐𝒍𝒂𝒓 𝑲𝒖𝒓𝒖 💵
# ₺9.6945
# 0.05%🔺
# 05-11-2021 15:30
# #USDTRY #dolar #MeralAbla,
# Created at: 2021-11-05 12:30:08+00:00
#
#
# Tweet ID: 1456599712103084032
# Text: RT @OpDrBilgehan: Katil Korona aşıları işledikleri suçlar üzerinde bıraktıkları parmak izlerini silmek için yüz milyonlarca dolar harcamaya…,
# Created at: 2021-11-05 12:30:08+00:00
#
#
# Tweet ID: 1456599706239385601
# Text: RT @RtradeCn: Bu hafta da 100 dolar verelim takipçilerimize.💵
# Hemen hemen her hafta yaparız demiştik🧿
# RT ve Beğeni yapanlardan 2 kişiye ben…,
# Created at: 2021-11-05 12:30:06+00:00
#
#
# Tweet ID: 1456599694348595214
# Text: *TCMB Kapanış Kurları: Dolar 9,7000 / 9,7175 TL, Euro 11,1995 / 11,2197 TL, Euro/Dolar 1,1546
#
# #iDeal,
# Created at: 2021-11-05 12:30:04+00:00
#
#
# Tweet ID: 1456599689227276297
# Text: Dolar: 9.7219
# Euro: 11.1972
# Altın Ons: $1792
# Gram Altın: 559,83
# Gümüş: 7,43
# Sterlin: 13.0761
# Güncellenme Zamanı: 15:29:58
# Anlık Döviz&amp;Altın Fiyatları Uygulaması(Android): https://t.co/eue7QXaADo
# #dolar #euro #altın,
# Created at: 2021-11-05 12:30:02+00:00
#
#
# Tweet ID: 1456599679009898503
# Text: ABD İklim Özel Temsilcisi Kerry: Gelişmekte olan ülkelere yıllık 100 milyar dolar fon hedefine 2022'de ulaşabiliriz
# https://t.co/zdVi5VUEL6,
# Created at: 2021-11-05 12:30:00+00:00
#
#
# Tweet ID: 1456599676036255752
# Text: @Vforrkripto ICP candır hedefim 350 dolar maliyetim 38 dolar,
# Created at: 2021-11-05 12:29:59+00:00
#
#
# Tweet ID: 1456599673389654018
# Text: Dolar alın https://t.co/qAqhhPNi8K,
# Created at: 2021-11-05 12:29:59+00:00
#
#
# Tweet ID: 1456599653265326080
# Text: RT @EremSenturk: Bak ben demiyorum Başak Hanım diyor: PKK destekçisi küresel sistem başta Selahattin Demirtaş ve arkadaşlarının terörle müc…,
# Created at: 2021-11-05 12:29:54+00:00
#
#
# Tweet ID: 1456599623779422214
# Text: RT @RefahHilvan: Maliye Bakanı "Doğalgazı 100'e alıp vatandaşa 25 birime satıyoruz" demiş büyük bir jestmiş gibi.
# Eğer TL bu kadar değer k…,
# Created at: 2021-11-05 12:29:47+00:00
#
#
# Tweet ID: 1456599620612771844
# Text: RT @solcugazete: New York Belediyesi, aşı olan 5-11 yaş arasındaki çocuklara 100 dolar hediye edecek,
# Created at: 2021-11-05 12:29:46+00:00
#
#
# Tweet ID: 1456599572780920836
# Text: RT @aa_finans: 🔸Petrol projeleri için uzun vadeli borçlanma maliyetleri yenilenebilir enerji yatırımlarına göre, yüzde 20 daha yüksek hale…,
# Created at: 2021-11-05 12:29:35+00:00
#
#
# Tweet ID: 1456599553017266179
# Text: RT @___ARSLAN___66: Cumhurbaşkanımız  EYT,yi çıkarsa hepsini emekli etse 4000 TL aylık verse
# Asgari ücret 7500 TL olsa
# Dolar tedavülden ka…,
# Created at: 2021-11-05 12:29:30+00:00
#
#
# Tweet ID: 1456599538072965124
# Text: RT @tarihvesehir: 1980 yapımı 'Tanrılar Çıldırmış Olmalı' filmi 60 milyon dolar hasılat yapmıştır. Başrolde oynayan siyahi oyuncu ise 300 d…,
# Created at: 2021-11-05 12:29:26+00:00
#
#
# Tweet ID: 1456599536563015682
# Text: RT @borsaparatic: Binance'dan USDT lerinizi dışarı çıkarıp gerçek dolar yaparken minimum efor ve sıfır kayıpla nasıl yapacağınızı anlatacağ…,
# Created at: 2021-11-05 12:29:26+00:00
#
#
# Tweet ID: 1456599530561052680
# Text: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :),
# Created at: 2021-11-05 12:29:25+00:00
#
#
# Tweet ID: 1456599521497161732
# Text: RT @kiyaslayan: 🌐 Dünyada Petrol Varil Fiyatları
#
# ▪️1 Yıl önce 43,4 dolar
# ▪️Bugün 82,5 dolar
# 🔼 Artış % 90
#
# 🇹🇷 Türkiye'de Benzin Pompa Fiyat…,
# Created at: 2021-11-05 12:29:22+00:00
#
#
# Tweet ID: 1456599514886836225
# Text: RT @tele1comtr: ➤Dolar haftaya yeni rekorla başladı: 10 lirayı zorluyor
# ➤Abdullah Gül sessizliğini bozdu: Gündeme ilişkin neler söyledi?
# ➤İ…,
# Created at: 2021-11-05 12:29:21+00:00
#
#
# Tweet ID: 1456599511065931784
# Text: @Dramatoryum Bunu DDR4 sistemim varken duymak acı verici, hele ki bu dolar kurunda.,
# Created at: 2021-11-05 12:29:20+00:00
#
#
# Tweet ID: 1456599510642302979
# Text: RT @FUATUGUR: “Dolar kocamı hapse attığınız için arttı” diyor kısaca. Biliyoruz bunu.Küresel finans çeteleri sadece kocan değil,içerdeki pe…,
# Created at: 2021-11-05 12:29:20+00:00
#
#
# Tweet ID: 1456599504585732098
# Text: RT @sozcumuratoglu: "10 ülkenin büyükelçisini" ülkede istemediğimizi açıklayınca olumsuz olarak algılanıp dolar artıyorsa⬆️
#
# Buna "gerek ka…,
# Created at: 2021-11-05 12:29:18+00:00
#
#
# Tweet ID: 1456599492095008777
# Text: Birazdan TDI verisi gelecek...
#
# Dolar/TL Short poz açıyorum
# Euro/Usd Long poz açıyorum
#
# #parite #Dolar #euro #usdtry
#
# Asla yazdıklarım yatırım tavsiyesi değildir,
# Created at: 2021-11-05 12:29:15+00:00
#
#
# Tweet ID: 1456599484063002624
# Text: RT @LeventUzumcu: Ötekileştirile ötekileştire dolar milyarderi olmuş bir çocuk.,
# Created at: 2021-11-05 12:29:13+00:00
#
#
# Tweet ID: 1456599466614697985
# Text: RT @freemind1923: Hepsini geçtim ordunun tepesine atadıkları Fetöcü subaylar darbeye kalkıp 250 insanı öldürdü, ekonomiye milyarlarca dolar…,
# Created at: 2021-11-05 12:29:09+00:00
#
#
# Tweet ID: 1456599464165220357
# Text: RT @serdardirican: Bir kenera yazın.
# PCR pozitif çıkan herkese bu Molnupiraviri dayayacaklar.
# Pahalı bir ilaç (kutusu 700 dolar)
# SGK'nın…,
# Created at: 2021-11-05 12:29:09+00:00
#
#
# Tweet ID: 1456599460931411971
# Text: RT @t_oncu: Para konusuyla ilgilenen arkadaşlara soru. Parayı bankacılık sistemi kredi vererek ve varlık alarak yarattığına göre, küresel b…,
# Created at: 2021-11-05 12:29:08+00:00
#
#
# Tweet ID: 1456599459069054977
# Text: @YolTV Hepsini geçtim ordunun tepesine atadıkları Fetöcü subaylar darbeye kalkıp 250 insanı öldürdü, ekonomiye milyarlarca dolar zarar verdi ve hiç utanmadan sıkılmadan bunu diyor.. diyebiliyor,
# Created at: 2021-11-05 12:29:08+00:00
#
#
# Tweet ID: 1456599450860859392
# Text: Mexc Borsasında Hesap açan herkese 200 Dolar Bonus Hediye Duyuru yeni yapıldı.
# Binance'nın yerını alacak bır Borsa platformu kayıt olup 200 doları alabılırsınız .
#
# https://t.co/jAgLOO1Wq9
#
# #Gaia #MEXC #BTC #Binance #Airdrop https://t.co/gHIFoRwejR,
# Created at: 2021-11-05 12:29:06+00:00
#
#
# Tweet ID: 1456599450055491589
# Text: ABD Dışişleri Bakanlığı Suudi Arabistan'a 640 milyon dolar değerinde 280 adet AIM-120C tipi Orta Menzilli Havadan Havaya Füze'nin satışına onay verdi.
#
# ABD Dışişleri Bakanlığı, söz konusu füzelerin Yemen'den yapılan hava saldırılarına yönelik savunma amaçlı olduğunu belirtti. https://t.co/qmaZFQmmkD,
# Created at: 2021-11-05 12:29:05+00:00
#
#
# Tweet ID: 1456599419474874370
# Text: @ozguradamTurk Dolar 2 tl ye inerse bu rakam bile yeterli ama zamlar devam ederse 10000 olsa ne olur,
# Created at: 2021-11-05 12:28:58+00:00
#
#
# Tweet ID: 1456599402563489797
# Text: @celikciyan Kardeşim önüne binlerce dolar koysalar donunu bile satarsın nft olarak...,
# Created at: 2021-11-05 12:28:54+00:00
#
#
# Tweet ID: 1456599399220514823
# Text: RT @1923nb: İki vatandaş arasında 128 milyar dolar tartışması üzerinden yumruk yumruğa kavga çıkt
RT @murselkanatoglu: Küreselciler de çok iyi biliyor ki Türkiye'de kendilerine kök söktüren kişi Berat Albayrak'tır
# Ülke'nin parasını gizli…,
# Created at: 2021-11-05 12:28:34+00:00
#
#
# Tweet ID: 1456599266303041541
# Text: Başka bir hesabımdan sıraya girerek girdiğim $IMX bana 200 $ alım hakkı çıkmış 😁😎 Diğer hesaptan keşke usdt olarak katılım sağlasaydım :) En az 1 dolar bekliyorum. https://t.co/RUveNjEMWH https://t.co/JabcdvRSQY,
# Created at: 2021-11-05 12:28:22+00:00
#
#
# Tweet ID: 1456599238868094976
# Text: RT @deryabuyukuncu: Ali Erbaş: “Diyanet, halkın en çok güvendiği ve sahiplendiği kurum.”
#
# Katılıyorum ama gülmekten.😂
#
# #TakunyalıFührer #Di…,
# Created at: 2021-11-05 12:28:15+00:00
#
#
# Tweet ID: 1456599236280209410
# Text: RT @murselkanatoglu: Küreselciler de çok iyi biliyor ki Türkiye'de kendilerine kök söktüren kişi Berat Albayrak'tır
# Ülke'nin parasını gizli…,
# Created at: 2021-11-05 12:28:14+00:00
#
#
# Tweet ID: 1456599217955291145
# Text: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :),
# Created at: 2021-11-05 12:28:10+00:00
#
#
# Tweet ID: 1456599213039575042
# Text: RT @___ARSLAN___66: Cumhurbaşkanımız  EYT,yi çıkarsa hepsini emekli etse 4000 TL aylık verse
# Asgari ücret 7500 TL olsa
# Dolar tedavülden ka…,
# Created at: 2021-11-05 12:28:09+00:00
#
#
# Tweet ID: 1456599207100420104
# Text: RT @___ARSLAN___66: Cumhurbaşkanımız  EYT,yi çıkarsa hepsini emekli etse 4000 TL aylık verse
# Asgari ücret 7500 TL olsa
# Dolar tedavülden ka…,
# Created at: 2021-11-05 12:28:07+00:00
#
#
# Tweet ID: 1456599189727682560
# Text: @atabenli olsun olsun tüyo verirse tam tersini yapar dolar alırız belki afadfsdgsfg,
# Created at: 2021-11-05 12:28:03+00:00
#
#
# Tweet ID: 1456599098942009346
# Text: RT @esilayanefesol: Siz hiç "ölmemek için" aç kaldınızmı?
#
# Kerimcan #fenerinmacivar
# #Fenerbahce #LiSA #Dolar #KaymakamMiraçBiziz https://t.…,
# Created at: 2021-11-05 12:27:42+00:00
#
#
# Tweet ID: 1456599098577068035
# Text: RT @kiyaslayan: 👉Türkiye'nin Afrika kıtasıyla ticareti;
#
# ▪️2002: 4,3 milyar dolar
#
# ▪️2020: 22 milyar dolar
#
# 👉Kıtadaki ticari temsilcilik sa…,
# Created at: 2021-11-05 12:27:42+00:00
#
#
# Tweet ID: 1456599079035801600
# Text: Gelişmekte olan piyasalarda gerilim artıyor #enflasyon #dolar #FED #borsa #hisse - https://t.co/J2k9lF59kM https://t.co/UriaCjng6H,
# Created at: 2021-11-05 12:27:37+00:00
#
#
# Tweet ID: 1456599074476539906
# Text: RT @CryptoBulls34: $EOS
#
# Eos tarafında 4 dolar civarı trend dip seviyemizdir. Altında hafta kapanışı stoploss olmak kaydı ile bu şekilde iz…,
# Created at: 2021-11-05 12:27:36+00:00
#
#
# Tweet ID: 1456599068826906627
# Text: RT @RtradeCn: Bu hafta da 100 dolar verelim takipçilerimize.💵
# Hemen hemen her hafta yaparız demiştik🧿
# RT ve Beğeni yapanlardan 2 kişiye ben…,
# Created at: 2021-11-05 12:27:34+00:00
#
#
# Tweet ID: 1456599041966592002
# Text: Gerer Yayını Sertçe
# Düşmanı Vurur Mertçe
#
# O cengiz Duruşu
# Turan'ın Kuruluşu
#
# duamız kabul olsun
# 360 milyar dolar bulunsun.
#
# türkiye kurtulsun.
# 4 milyon kiracı ve işsiz kurtulsun
#
# molla muzaffer iktidar olsun,
# Created at: 2021-11-05 12:27:28+00:00
#
#
# Tweet ID: 1456599014930010118
# Text: @Fatmacn0 1 milyar dolar için lüksemburg'tan dileniyorduk,
# Created at: 2021-11-05 12:27:22+00:00
#
#
# Tweet ID: 1456599013730525184
# Text: Everest'e "İmam Hatipler Kapatılsın" yazmak için
#  tırmanırken fenalaşan
# Merve Bakdur
#  gözünü hastanede açtı.
#
# 7500 dolar helikopter parasını ödeyemeyince rehin alındığı hastaneden İmamhatipli Cumhurbaşkanı'nın
#  talimatıyla kurtarıldı.
# Text: RT @FUATUGUR: “Dolar kocamı hapse attığınız için arttı” diyor kısaca. Biliyoruz bunu.Küresel finans çeteleri sadece kocan değil,içerdeki pe…,
# Created at: 2021-11-05 12:25:05+00:00
#
#
# Tweet ID: 1456598435180724238
# Text: @milyonerzihin @BlueZillaVc @PulsechainCom @PulsePad_App #pulsepad  3 dolar listenleme,
# Created at: 2021-11-05 12:25:03+00:00
#
#
# Tweet ID: 1456598429963071490
# Text: RT @yagmurdeniz_sma: @startv Sma hastası Yağmur'un 2 milyon dolar değerindeki ilacını alabilmemiz için hepinizin az da olsa bağışlarına iht…,
# Created at: 2021-11-05 12:25:02+00:00
#
#
# Tweet ID: 1456598421704413184
# Text: RT @Osmanzmen16: Maliye Bakanı "Doğalgazı 100'e alıp vatandaşa 25 birime satıyoruz" demiş büyük bir jestmiş gibi.
# Eğer TL bu kadar değer k…,
# Created at: 2021-11-05 12:25:00+00:00
#
#
# Tweet ID: 1456598397998280706
# Text: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :),
# Created at: 2021-11-05 12:24:55+00:00
#
#
# Tweet ID: 1456598387441160194
# Text: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :),
# Created at: 2021-11-05 12:24:52+00:00
#
#
# Tweet ID: 1456598381334249477
# Text: 150 milyar dolar servet de çalsan, boğazından geçen en fazla midenin alacağı kadar, o da Allah'ın verdiği sayılı günler boyunca!
# Değer miydi bu dünyada bırakacağın varlıklar için milyonlarca masuma zulmetmeye?
# Sırf maaş/makam/para için şu zalime yaslananlar, kral da ölür bir gün. https://t.co/kuFFWHLobP,
# Created at: 2021-11-05 12:24:51+00:00
#
#
# Tweet ID: 1456598379862048777
# Text: RT @Seyfett39479898: Başkanlık sistemi gelirse,
# Türkiye uçacak dediler,
# Evet,türkiye uçtu,
# Ama zenginliğe deyil,yoksulluga  uçtu.
#
# Hak,adal…,
# Created at: 2021-11-05 12:24:50+00:00
#
#
# Tweet ID: 1456598377995636736
# Text: RT @el_patrone_bist: size #dolar #xu100 korelasyonunu göstereyim
#
# eğer dolar 1.resimde ki yerden aşağı gelir
#
# eğer #XU100  2.resimde ki yer…,
# Created at: 2021-11-05 12:24:50+00:00
#
#
# Tweet ID: 1456598377701916688
# Text: Dolar💸💸💸💸💸 https://t.co/bmNh1hnK84,
# Created at: 2021-11-05 12:24:50+00:00
#
#
# Tweet ID: 1456598354373320705
# Text: @aybuseuslu Abi ne olmuş yani bir dolar geldiyse chat herkes yapıyor saçmalamaz mısınız acaba,
# Created at: 2021-11-05 12:24:44+00:00
#
#
# Tweet ID: 1456598350522949632
# Text: @solhaberportali Azmin, çalışkanlığın  kitabını yazsinda bizde yararlanalim  26 milyar dolar nasil kazanilir,
# Created at: 2021-11-05 12:24:43+00:00
#
#
# Tweet ID: 1456598350053224456
# Text: @YolTV ekonomistler basketbol oynarken, dolar 9.72 olmustu
# milyonlar acliktan kiriliyor
# fakir,fukara,garip,gureba copten ekmek topluyordu,
# Created at: 2021-11-05 12:24:43+00:00
#
#
# Tweet ID: 1456598331782795269
# Text: Maliye Bakanı "Doğalgazı 100'e alıp vatandaşa 25 birime satıyoruz" demiş büyük bir jestmiş gibi.
# Eğer TL bu kadar değ
# Tweet ID: 1456598011883175936
# Text: @iyiolunn @NoContextSag Boraz araştırdım,kısmen haklısın ama doları assaya çekmek  kolay dısardan hicbirsey alma kendin daha maliyetli uret dolar düşer ama bu kezde ekonomi dahada kotüye gider. Lafı eveleyip gevelemeyin doların bize yakın oldugu ulkeler üretiyor dışariya satıyor zarar etmiyor çözümde bu,
# Created at: 2021-11-05 12:23:22+00:00
#
#
# Tweet ID: 1456598011342118914
# Text: @kemalkaptan1960 @Atakz37221759 @Akparti 2005 yılında dolar 1.15 idi. O zaman Tayyip boyun eğmiş demek ki.,
# Created at: 2021-11-05 12:23:22+00:00
#
#
# Tweet ID: 1456597972800659460
# Text: RT @nimetatas34: Başak Demirtaş Diyarbakır'dan bir Kürt genci olarak seninle bu yıllar konusunda kim kime borçlu hesap yaptım .Ve görüyorum…,
# Created at: 2021-11-05 12:23:13+00:00
#
#
# Tweet ID: 1456597972670689282
# Text: RT @1881Erdem: #BNB de kalkışma varmış gelsin bakalım en son En tepede verdik 688 .88 alanda kazansın dedik ama alan battı 225 dolar geldi.…,
# Created at: 2021-11-05 12:23:13+00:00
#
#
# Tweet ID: 1456597965263495172
# Text: RT @EremSenturk: Bak ben demiyorum Başak Hanım diyor: PKK destekçisi küresel sistem başta Selahattin Demirtaş ve arkadaşlarının terörle müc…,
# Created at: 2021-11-05 12:23:11+00:00
#
#
# Tweet ID: 1456597965146136576
# Text: RT @tugceicozu: #Girişim henüz fikir aşamasındayken ilgisini gösteren ve süreçte @Omnicourse’a düzenli destek olan @angeleffectco , Omnicou…,
# Created at: 2021-11-05 12:23:11+00:00
#
#
# Tweet ID: 1456597926474625031
# Text: RT @misvakcaps: Everest'e "İmam Hatipler Kapatılsın" yazmak için tırmanırken fenalaşan Merve Bakdur gözünü hastanede açtı.
#
# 7500 dolar heli…,
# Created at: 2021-11-05 12:23:02+00:00
#
#
# Tweet ID: 1456597919939825664
# Text: TDI verisi 15:30 da ama beklenti gercekten cok yuksek bu veriye gore beklenti ve uzeri kalmasi ciddi hareketler yarayacaktir ama bir yandan dolar endeksi yaptirimlar cok guclu tutuldu ve ben bunun surecegini dusunuyorum risk alinacak bir islem olacaktir ben riske girebilirim ama,
# Created at: 2021-11-05 12:23:01+00:00
#
#
# Tweet ID: 1456597919021293573
# Text: RT @ercanfaras: Örneğin Panama Kanalı'ndan günde ortalama 40 gemi geçiyor;
# Yıllık yaklaşık 2 milyar dolar gelir elde ediyor.
#
# Süveyş Kanalı…,
# Created at: 2021-11-05 12:23:00+00:00
#
#
# Tweet ID: 1456597878919532545
# Text: RT @1881Erdem: #BNB son mavi çizgiye dikkat 688.88 de sattık 692 en tepe bu işi yapıyoruz dostlar Teknik analiz nasıl çalışır incele #Erdem…,
# Created at: 2021-11-05 12:22:51+00:00
#
#
# Tweet ID: 1456597866328297483
# Text: #ICP #ıcp #ICPUSDT Hedefler geçerli 47 dolar önemli bir dirençti içinden geçildi… Görüntüdeki hedefler çok hızlı gelecektir… https://t.co/Kn49Fc2uh0,
# Created at: 2021-11-05 12:22:48+00:00
#
#
# Tweet ID: 1456597863035703296
# Text: @yenisafak Dolar fırlamış aldı başına gidiyor her gün zam üstüne zam devletin kasası tam bakır kuru bakır  çıkmışsınız Müslümanlıktan dinden bahsediyorsunuz ayıptır Madem yönetenler çok müslüman neden devletin kasası boş uçan kuştan vergi alınan bir ülkede yaşıyoruz,
# Created at: 2021-11-05 12:22:47+00:00
#
#
# Tweet ID: 1456597848900898824
# Text: RT @VatandasTube: İki vatandaş arasında 128 milyar dolar tartışması üzerinden yumruk yumruğa kavga çıktı. Via/@Zeyrek_00
# #BirŞeylerOlduGerç…,
# Created at: 2021-11-05 12:22:44+00:00
#
#
# Tweet ID: 1456597829472985097
# Text: @rogarkap @XYZ92071862 @yengecchuseyin @aykut2708_ @ProfDemirtas @armag Bunu diyen ülkeyi de abd tehdit olarak görüp yerle bir etmek için elinden geleni yapıyor
#
# Mesela Rusya rezervlerinden doları çıkardı
#
# Ancak dünya ölçeğinde küçücük bir etkiye sebep oldu
#
# Dolar rezerv para olmaktan çıkarsa abd halkı en az %25-30 Fakirleşir,
# Created at: 2021-11-05 12:22:39+00:00
#
#
# Tweet ID: 1456597814327250945
# Text: RT @murselkanatoglu: Küreselciler de çok iyi biliyor ki Türkiye'de kendilerine kök söktüren kişi Berat Albayrak'tır
# Ülke'nin parasını gizli…,
# Created at: 2021-11-05 12:22:35+00:00
#
#
# Tweet ID: 1456597808195293189
# Text: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :),
# Created at: 2021-11-05 12:22:34+00:00
#
#
# Tweet ID: 1456597804466548736
# Text: RT @dw_turkce: ABD Dışişleri Bakanlığı Suudi Arabistan'a 640 milyon dolar değerinde 280 adet AIM-120C tipi Orta Menzilli Havadan Havaya Füz…,
# Created at: 2021-11-05 12:22:33+00:00
#
#
# Tweet ID: 1456597798351147008
# Text: RT @ogretmenlersyfs: Açık öğretim sınav görev ücretleri dolar 3 lirayken 80-90 liraydı şimdi dolar 10 lira oldu 100-110 lira civarı.
# Arkad…,
# Created at: 2021-11-05 12:22:32+00:00
#
#
# Tweet ID: 1456597776003969031
# Text: #BNB son mavi çizgiye dikkat 688.88 de sattık 692 en tepe bu işi yapıyoruz dostlar Teknik analiz nasıl çalışır incele #Erdembayram #BTC ath sini 1 dolar fark ile  tahmin etmişdir Zirvedir. https://t.co/N0rK6KfUBJ,
# Created at: 2021-11-05 12:22:26+00:00
#
#
# Tweet ID: 1456597771872522244
# Text: @rogarkap @XYZ92071862 @yengecchuseyin @aykut2708_ @ProfDemirtas @armag Mevcut para sistemine bir alternatif gelmediği sürece dolar anlamlı bir değer kaybı yaşamaz
# Amerika cari açık verdikçe diğer ülkelerin rezervi artar
#
# Bu sistem ancak diğer ülkelerin dolarla ticaret yapmıyorum
# Amerikan tahvili almıyorum
# Dolar rezervi tutmuyorum demesiyle son bulur,
# Created at: 2021-11-05 12:22:25+00:00
#
#
# Tweet ID: 1456597745444261889
# Text: @CryptoHunterTR Kasım ayına 80 dolar zararda başladım ilaç olur,
# Created at: 2021-11-05 12:22:19+00:00
#
#
# Tweet ID: 1456597745381281795
# Text: RT @Su_Demsltn: Everest'e varınca karlara 'İmam Hatipler Kapatılsın' yazma düşüncesinde olan Merve Bakdur, Everest'e çıkarken fenalaştı.
# He…,
# Created at: 2021-11-05 12:22:19+00:00
#
#
# Tweet ID: 1456597745200939010
# Text: RT @RtradeCn: Bu hafta da 100 dolar verelim takipçilerimize.💵
# Hemen hemen her hafta yaparız demiştik🧿
# RT ve Beğeni yapanlardan 2 kişiye ben…,
# Created at: 2021-11-05 12:22:19+00:00
#
#
# Tweet ID: 1456597728595750915
# Text: RT @misvakcaps: Everest'e "İmam Hatipler Kapatılsın" yazmak için tırmanırken fenalaşan Merve Bakdur gözünü hastanede açtı.
#
# 7500 dolar heli…,
# Created at: 2021-11-05 12
# Text: RT @RtradeCn: Bu hafta da 100 dolar verelim takipçilerimize.💵
# Hemen hemen her hafta yaparız demiştik🧿
# RT ve Beğeni yapanlardan 2 kişiye ben…,
# Created at: 2021-11-05 12:21:37+00:00
#
#
# Tweet ID: 1456597568721391616
# Text: RT @RtradeCn: Bu hafta da 100 dolar verelim takipçilerimize.💵
# Hemen hemen her hafta yaparız demiştik🧿
# RT ve Beğeni yapanlardan 2 kişiye ben…,
# Created at: 2021-11-05 12:21:37+00:00
#
#
# Tweet ID: 1456597567979114500
# Text: @Ez_ki_me @ErfanKarami17 Ger bibe wek Îranê, divê hûn dolar bikirin,Otomobîl bikirin, zêr bikirin, mal bikirin. Ji ber ku dê giran bibin,
# Created at: 2021-11-05 12:21:37+00:00
#
#
# Tweet ID: 1456597563730169865
# Text: RT @yillar_kayip: Emniyet müdürü bir arkadaş vardı eşi parasızlıktan dolayı 5 ayda bir geliyordu.😔 garibim içine ata ata midesi bitmişti  n…,
# Created at: 2021-11-05 12:21:36+00:00
#
#
# Tweet ID: 1456597543979077638
# Text: RT @VatandasTube: Bilal Erdoğan: Bugün öyle bir hızla ilerliyoruz ki, Türkiye öyle bir fırsat penceresini yakalamış durumda ki, 6 ay 1 yıl…,
# Created at: 2021-11-05 12:21:31+00:00
#
#
# ...
# Text: 23 Ekim 2021 dolar kuru 9.60
#
# 5 Kasıl 2021 dolar kuru 9.70
#
# Fark % 1,
# Created at: 2021-11-05 12:13:08+00:00
#
#
# Tweet ID: 1456595428045213698
# Text: RT @srdrmrtsn: Bnb için 300 dolar civarıyken 600 dolar hedefi vermiştim.
#
# Bu hedefte gerçekleşti✅
#
# 600-1000 arasına girer orada kademeli sa…,
# Created at: 2021-11-05 12:13:06+00:00
#
#
# Tweet ID: 1456595427101454343
# Text: RT @misvakcaps: Everest'e "İmam Hatipler Kapatılsın" yazmak için tırmanırken fenalaşan Merve Bakdur gözünü hastanede açtı.
#
# 7500 dolar heli…,
# Created at: 2021-11-05 12:13:06+00:00
#
#
# Tweet ID: 1456595423917920257
# Text: RT @hanifhuman: Newyork çocuğunu Işılatan herkese 100 dolar veriyoruz
# Evet çocuk başı 100 dolar
# Yan etki miyokardit kalp iltihabı https://t…,
# Created at: 2021-11-05 12:13:05+00:00
#
#
# Tweet ID: 1456595421757943809
# Text: RT @goldencrossgc: Mana coinin hedefi 7-8 dolar civarıdır ilk etapta.,
# Created at: 2021-11-05 12:13:05+00:00
#
#
# Tweet ID: 1456595407597879301
# Text: RT @OpDrBilgehan: Katil Korona aşıları işledikleri suçlar üzerinde bıraktıkları parmak izlerini silmek için yüz milyonlarca dolar harcamaya…,
# Created at: 2021-11-05 12:13:02+00:00
#
#
# Tweet ID: 1456595406457090048
# Text: Trending on #LunarCrush:
#
# "ARKADAŞLAR YOYOWUN TAKTİĞİ SAYESİNDE 11 DOLARIM ARTIK 11 MİLYON DOLAR OLDU TEŞEKKÜRLER YOYOW VE ÖĞE DENETLEYİCİSİ🥰🥰🥰
# .
# .
# .
# .
# .
#
# #shiba #LUNA #doge ..." via @Cikancoin22
#
# Top coin mentions
# $yoyow
#
# https://t.co/U2xeHKmoWa #LunarShare,
# Created at: 2021-11-05 12:13:01+00:00
#
#
# Tweet ID: 1456595397787459584
# Text: RT @mericein: @___ARSLAN___66 Cumhurbaşkanımız  EYT,yi çıkarsa hepsini emekli etse 4000 TL aylık verse
# Asgari ücret 7500 TL olsa
# Dolar ted…,
# Created at: 2021-11-05 12:12:59+00:00
#
#
# Tweet ID: 1456595397460299776
# Text: RT @misvakcaps: Everest'e "İmam Hatipler Kapatılsın" yazmak için tırmanırken fenalaşan Merve Bakdur gözünü hastanede açtı.
#
# 7500 dolar heli…,
# Created at: 2021-11-05 12:12:59+00:00
#
#
# Tweet ID: 1456595376820080645
# Text: RT @murselkanatoglu: Küreselciler de çok iyi biliyor ki Türkiye'de kendilerine kök söktüren kişi Berat Albayrak'tır
# Ülke'nin parasını gizli…,
# Created at: 2021-11-05 12:12:54+00:00
#
#
# Tweet ID: 1456595376761360392
# Text: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :),
# Created at: 2021-11-05 12:12:54+00:00
#
#
# Tweet ID: 1456595375326892039
# Text: RT @ozturkyilmazYP: Cumhur ve Millet İttifakları Ülkemizi Bitirecek!
#
# #4Kasım #ittifak #dolar
#
# https://t.co/EpINb8gQzr,
# Created at: 2021-11-05 12:12:54+00:00
#
#
# Tweet ID: 1456595364807692297
# Text: 7️⃣bunu aşağı yönlü 175 milyon dolar olarak revize etmişler , özellikle petrol ürün marjlarındaki yükselişe bağlı rafineri  sektör performans göstergesi olarak Akdeniz rafineri marjı ve Tüpraş rafineri marj beklentisi yukarı yönlü bir marj petrol fiyatlarındaki hareketle,
# Created at: 2021-11-05 12:12:51+00:00
#
#
# Tweet ID: 1456595363062640643
# Text: 6️⃣öngörüsünü bu sefer 4.5 ila 5 dolar/varil seviyesine getirmiş 📌Operasyonel hedeflerindeki kapasite kullanım oranı %85-%90’lık bir kapasite kullanım öngörüsü var , üretim 25/26 milyon ton, toplam satışlar 26/27 milyon ton, toplam yatırım beklentisi de 200 milyon dolardı,
# Created at: 2021-11-05 12:12:51+00:00
#
#
# Tweet ID: 1456595357568323584
# Text: 5️⃣Öngörüleri var , revizyonları var Akdeniz rafineri marjı beklentileri var ilk 1.5/2 dolar /Varil gerçekleşmesi ,bekleniyor yani bunu 0ila 0,5 aralığında yukarı yönlü güncellenmişler , net rafineri marjı beklentisine baktığımızda daha öncesindeki 2.5 ila 3.5 arasındaki,
# Created at: 2021-11-05 12:12:50+00:00
#
#
# Tweet ID: 1456595355248779274
# Text: Trending on #LunarCrush:
#
# "ARKADAŞLAR YOYOWUN TAKTİĞİ SAYESİNDE 11 DOLARIM ARTIK 11 MİLYON DOLAR OLDU TEŞEKKÜRLER YOYOW VE ÖĞE DENETLEYİCİSİ🥰🥰🥰
# .
# .
# .
# .
# .
#
# #shiba #LUNA #doge ..." via @Cikancoin22
#
# Top coin mentions
# $yoyow
#
# https://t.co/ww4JuWmONz #LunarShare,
# Created at: 2021-11-05 12:12:49+00:00
#
#
# Tweet ID: 1456595351318769664
# Text: RT @EremSenturk: Asgari ücret hayat pahalılığına çare olur mu?
#
# Not Defteri ⏰ 14.30
#
# 📌“Dolar para değildir” itirafı.
# 📌CHP’nin lahana turşus…,
# Created at: 2021-11-05 12:12:48+00:00
#
#
# Tweet ID: 1456595344255590400
# Text: RT @buradamiyizz: Beni kaybetmek üzeresin
#
# #camdakikiz #Straykids #hayirlicumalar #instagramdown #LiSA #Dolar #FCLMvGS #MAMA2021 #topmodel…,
# Created at: 2021-11-05 12:12:46+00:00
#
#
# Tweet ID: 1456595337989210118
# Text: RT @___ARSLAN___66: Cumhurbaşkanımız  EYT,yi çıkarsa hepsini emekli etse 4000 TL aylık verse
# Asgari ücret 7500 TL olsa
# Dolar tedavülden ka…,
# Created at: 2021-11-05 12:12:45+00:00
#
#
# Tweet ID: 1456595332649869313
# Text: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :),
# Created at: 2021-11-05 12:12:44+00:00
#
#
# Tweet ID: 1456595314207567879
# Text: RT @solcugazete: New York Belediyesi, aşı olan 5-11 yaş arasındaki çocuklara 100 dolar hediye edecek,
# Created at: 2021-11-05 12:12:39+00:00
#
#
# Tweet ID: 1456595306779398145
# Text: Trending on #LunarCrush:
#
# "ARKADAŞLAR YOYOWUN TAKTİĞİ SAYESİNDE 11 DOLARIM ARTIK 11 MİLYON DOLAR OLDU TEŞEKKÜRLER YOYOW VE ÖĞE DENETLEYİCİSİ🥰🥰🥰
# .
# .
# .
# .
# .
#
# #shiba #LUNA #doge ..." via @Cikancoin22
#
# Top coin mentions
# $yoyow
#
# https://t.co/Sn6zQ5BVqj #LunarShare,
# Created at: 2021-11-05 12:12:38+00:00
#
#
# Tweet ID: 1456595303075876867
# Text: @eness_turann İkinizide tanımıyorum ikinizide aylardır takip ediyorum. @RealYoyowbu  çoğu alım satımını canlı videolarla gösteriyor. Başka canlı yapan kimseyi görmedim. Birde adam milyon dolarlar ile işlem yapıyor, milleti 5-10 bin dolar dolandırıyor demen hırsız demen pek inandırıcı gelmiyor.,
# Created at: 2021-11-05 12:12:37+00:00
#
#
# Tweet ID: 1456595292590051330
# Text: Trending on #LunarCrush:
#
# "ARKADAŞLAR YOYOWUN TAKTİĞİ SAYESİNDE 11 DOLARIM ARTIK 11 MİLYON DOLAR OLDU TEŞEKKÜRLER YOYOW VE ÖĞE DENETLEYİCİSİ🥰🥰🥰
# .
# .
# .
# .
# .
#
# #shiba #LUNA #doge ..." via @Cikancoin22
#
# Top coin mentions
# $yoyow
#
# https://t.co/5DNmNM619p #LunarShare,
# Created at: 2021-11-05 12:12:34+00:00
#
#
# Tweet ID: 1456595286034468872
# Text: @fahrettinaltun @lutfielvan Sen ne zaman yalanladın da yalan olduğu ortaya çıktı. @RTErdogan yürüyebiliyor mu?
# 27 trilyon dolar zarara uğrattınız hesap vereceksiniz.,
# Created at: 2021-11-05 12:12:33+00:00
#
#
# Tweet ID: 1456595249644572676
# Text: RT @ilhangunes58: Lütfi Elvan istifa etti "şimdilik" kabul edilmedi, diyorlar ,ekonominin başına yeniden ,Berat Albayrak veya
# Bilal Erdoğa…,
# Created at: 2021-11-05 12:12:24+00:00
#
#
# Tweet ID: 1456595246708674566
# Text: RT @misvakcaps: Everest'e "İmam Hatipler Kapatılsın" yazmak için tırmanırken fenalaşan Merve Bakdur gözünü hastanede açtı.
#
# 7500 dolar heli…,
# Created at: 2021-11-05 12:12:23+00:00
#
#
# Tweet ID: 1456595229126037507
# Text: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :),
# Created at: 2021-11-05 12:12:19+00:00
#
#
# Tweet ID: 1456595181436903430
# Text: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :),
# Created at: 2021-11-05 12:12:08+00:00
#
#
# Tweet ID: 1456595180304441351
# Text: RT @RtradeCn: Bu hafta da 100 dolar verelim takipçilerimize.💵
# Hemen hemen her hafta yaparız demiştik🧿
# RT ve Beğeni yapanlardan 2 kişiye ben…,
# Created at: 2021-11-05 12:12:07+00:00
#
#
# Tweet ID: 1456595179843080195
# Text: Bilal Erdoğan: "Bugün öyle bir hızla ilerliyoruz ki Türkiye öyle bir fırsat penceresini yakalamış durumda ki muhtemelen yakın zamanda 6 ay 1 yıl sürmeden Türkiye, her iş gününde 1 milyar dolar ihracat yapan bir ülke haline gelmiş olacak",
# Created at: 2021-11-05 12:12:07+00:00
#
#
# Tweet ID: 1456595137774170118
# Text: @omerteksas @RTErdogan Bence ülke olarak para birimi izin dolar olması lazım ancak ozaman başa çıkabiliriz. Çıkar sağlamayı bir kenara bıraktıkları zaman bu gerçekleşecek zaten,
# Created at: 2021-11-05 12:11:57+00:00
#
#
# Tweet ID: 1456595120564936705
# Text: RT @misvakcaps: Everest'e "İmam Hatipler Kapatılsın" yazmak için tırmanırken fenalaşan Merve Bakdur gözünü hastanede açtı.
#
# 7500 dolar heli…,
# Created at: 2021-11-05 12
# Text: RT @misvakcaps: Everest'e "İmam Hatipler Kapatılsın" yazmak için tırmanırken fenalaşan Merve Bakdur gözünü hastanede açtı.
#
# 7500 dolar heli…,
# Created at: 2021-11-05 12:11:40+00:00
#
#
# Tweet ID: 1456595042987032579
# Text: RT @c_chiliz: #dogecoin her ne kadar şaka para birimi olsan da piyasadaki sempatim ve benimsenmen seni #1$ dolar yapacaktır #doge,
# Created at: 2021-11-05 12:11:35+00:00
#
#
# Tweet ID: 1456595040776642564
# Text: @atabenli Dolar,bunu beğendi.,
# Created at: 2021-11-05 12:11:34+00:00
#
#
# Tweet ID: 1456595036125138944
# Text: RT @ustadsplinter34: $jup 0.02- 16 milyon dolar marketcap
# $mtv 0.024- 80 milyon dolar marketcap
# $cspr 0.12- 300 milyon dolar mcap
# akıllı sö…,
# Created at: 2021-11-05 12:11:33+00:00
#
#
# Tweet ID: 1456595008715477001
# Text: @Sancaktarr34 @mturktma @haskologlu La suriyeye girmişsin 10 km yanında 90 bin kişilik pkk ordusu kurulmuş ypg ye en son ne zman operasyon yapıldı !! Aaa yapılmamış 5 milyon suriyelihe 40 milyar dolar harcamıs halkını sefalete sürüklemişsin 100 lerce şehit vermissin sonuç sıfır rakamla 0.,
# Created at: 2021-11-05 12:11:26+00:00
#
#
# Tweet ID: 1456595001991995400
# Text: RT @nimetatas34: Başak Demirtaş Diyarbakır'dan bir Kürt genci olarak seninle bu yıllar konusunda kim kime borçlu hesap yaptım .Ve görüyorum…,
# Created at: 2021-11-05 12:11:25+00:00
#
#
# Tweet ID: 1456594993901146114
# Text: @cryptomercan ltc 2k dolar olur yazmış. buna hoca diyip şişiren de suç. hahahaha,
# Created at: 2021-11-05 12:11:23+00:00
#
#
# Tweet ID: 1456594990205964291
# Text: -Bist 100 dirence çok yakın. Temkinli olunmalı
#
# -Dolar/TL yukarı. Dün konuştuk.
#
# -Bitcoin ve Etherium yükselen trendde ve tehlikesiz bölgede. Dün konuştuk. Buralara dinlenmeleri güç kazandırır.
#
# -Alt coinlerde tüm analizlerim geçerlidir. Hepsi güncel.
#
# Bol kazançlar,
# Created at: 2021-11-05 12:11:22+00:00
#
#
# Tweet ID: 1456594984677920775
# Text: RT @EremSenturk: Bak ben demiyorum Başak Hanım diyor: PKK destekçisi küresel sistem başta Selahattin Demirtaş ve arkadaşlarının terörle müc…,
# Created at: 2021-11-05 12:11:21+00:00
#
#
# Tweet ID: 1456594982089805829
# Text: Trending on #LunarCrush:
#
# "ARKADAŞLAR YOYOWUN TAKTİĞİ SAYESİNDE 11 DOLARIM ARTIK 11 MİLYON DOLAR OLDU TEŞEKKÜRLER YOYOW VE ÖĞE DENETLEYİCİSİ🥰🥰🥰
# .
# .
# .
# .
# .
#
# #shiba #LUNA #doge ..." via @Cikancoin22
#
# Top coin mentions
# $yoyow
#
# https://t.co/RmO36n0pux #LunarShare,
# Created at: 2021-11-05 12:11:20+00:00
#
#
# Tweet ID: 1456594954785017857
# Text: RT @RtradeCn: Bu hafta da 100 dolar verelim takipçilerimize.💵
# Hemen hemen her hafta yaparız demiştik🧿
# RT ve Beğeni yapanlardan 2 kişiye ben…,
# Created at: 2021-11-05 12:11:14+00:00
#
#
# Tweet ID: 1456594953224732672
# Text: @pardesse_prens Dolar bazında belini yeni doğrultuyor gibi https://t.co/4SZIzu2viJ,
# Created at: 2021-11-05 12:11:13+00:00
#
#
# Tweet ID: 1456594948753666051
# Text: @KingofBtc Allah razı olsun King. Bide coti den kurtulursam 50 dolar göndericem öğrenci kardeşlerime. Bırakmıyor Coti peşimi,
# Created at: 2021-11-05 12:11:12+00:00
#
#
# Tweet ID: 1456594932194492419
# Text: Dolar speedrun videosu youtubeye ne zaman yüklenir,
# Created at: 2021-11-05 12:11:08+00:00
#
#
# Tweet ID: 1456594932114853901
# Text: @YusufTo42816729 @YolTV @Neriman1903BJ Ufak tefek dediğin milyarca dolar.,
# Created at: 2021-11-05 12:11:08+00:00
#
#
# Tweet ID: 1456594919477370884
# Text: RT @AllektaMuvik: 1 #dolar 9,74 TL.. Sorumlu kim?
#
# A) Kılıçdaroğlu
# B) Dış minnaklar
# C) Kebapçılar
# D) Dürriyenin Güğümleri
#
# #KaranlıktanÇıkı…,
# Created at: 2021-11-05 12:11:05+00:00
#
#
# Tweet ID: 1456594898237509637
# Text: RT @canyilmaz1: Gram altın güne 560 TL seviyesinde başladı, çeyrek altın 915 TL seviyesinde başladı, dolar şöyle başladı euro böyle başladı…,
# Created at: 2021-11-05 12:11:00+00:00
#
#
# Tweet ID: 1456594891958542336
# Text: #dogecoin her ne kadar şaka para birimi olsan da piyasadaki sempatim ve benimsenmen seni #1$ dolar yapacaktır #doge,
# Created at: 2021-11-05 12:10:59+00:00
#
#
# Tweet ID: 1456594886556278788
# Text: RT @NejatOzonay: Reel Efektif Döviz Kuru Ekim ayında 60.37’ye geriledi
#
# TL yeterince değersiz,ihracatı desteklemek için Dolar’ı daha fazla…,
# Created at: 2021-11-05 12:10:57+00:00
#
#
# Tweet ID: 1456594885918740483
# Text: @bergenimden Dolar,
# Created at: 2021-11-05 12:10:57+00:00
#
#
# Tweet ID: 1456594863332499463
# Text: RT @misvakcaps: Everest'e "İmam Hatipler Kapatılsın" yazmak için tırmanırken fenalaşan Merve Bakdur gözünü hastanede açtı.
#
# 7500 dolar heli…,
# Created at: 2021-11-05 12:10:52+00:00
#
#
# Tweet ID: 1456594848849539079
# Text: RT @TurhanBozkurTV: Japon hükûmeti yeni ekonomik teşvik paketinde 18 yaş altındaki her çocuk başına 100 bin yen (880 dolar) hibe edecek.,
# Created at: 2021-11-05 12:10:48+00:00
#
#
# Tweet ID: 1456594841408782337
# Text: RT @ercanfaras: Örneğin Panama Kanalı'ndan günde ortalama 40 gemi geçiyor;
# Yıllık yaklaşık 2 milyar dolar gelir elde ediyor.
#
# Süveyş Kanalı…,
# Created at: 2021-11-05 12:10:47+00:00
#
#
# Tweet ID: 1456594825181110273
# Text: @milyonerzihin @BlueZillaVc @PulsechainCom @PulsePad_App Kac bin dolar kitlememiz gerekiyor bilgisi olan varmı,
# Created at: 2021-11-05 12:10:43+00:00
#
#
# Tweet ID: 1456594818763796485
# Text: RT @borsaparatic: Binance'dan USDT lerinizi dışarı çıkarıp gerçek dolar yaparken minimum efor ve sıfır kayıpla nasıl yapacağınızı anlatacağ…,
# Created at: 2021-11-05 12:10:41+00:00
#
#
# Tweet ID: 1456594812442906633
# Text: RT @FurkanSolmazTR: Everest’e tırmanırken fenalaşan Merve Bakdur, Katmandu'da gözünü açtığında helikopter masrafı olarak 7 bin 500 dolar bo…,
# Created at: 2021-11-05 12:10:40+00:00

# %% [markdown]
# ## 5. Writing Tweets to a text file
#
# - This example shows how you can write the Tweet IDs for each Tweet obtained for a search result, to a text file.
# - Make sure to replace the `file_name` with the a name of your chosing.
# - If you wish to write other fields to the text file, make sure to adjust the script below accordingly.
# - Python code example:
#
# ```python
# client = tweepy.Client(bearer_token='REPLACE_ME')
#
# # Replace with your own search query
# query = 'covid -is:retweet'
#
# # Name and path of the file where you want the Tweets written to
# file_name = 'tweets.txt'
#
# with open(file_name, 'a+') as filehandle:
#     for tweet in tweepy.Paginator(client.search_recent_tweets, query=query,
#                                   tweet_fields=['context_annotations', 'created_at'], max_results=100).flatten(
#             limit=1000):
#         filehandle.write('%s\n' % tweet.id)
# ```

# %%
client = tweepy.Client(bearer_token=bearer_token)

query = 'dolar lang:tr'

file_name = 'tweets.txt'

with open(file_name, 'a+', encoding="utf-8") as filehandle:
    for tweet in tweepy.Paginator(client.search_recent_tweets, query=query,
                                  tweet_fields=['created_at'], max_results=100).flatten(
            limit=200):
        filehandle.write(f"Tweet ID: {tweet.id}\nText: {tweet.text},\nCreated at: {tweet.created_at}\n\n", )

# %% [markdown]
# ## 6. Getting Tweets with user information, for each Tweet
#
# - If you need additional information associated with the Tweet, such as the information of the user Tweeting it, you can use [expansions](https://developer.twitter.com/en/docs/twitter-api/expansions) and pass it to the `search_recent_tweets` function.
# - In this example, we want user information, which is why the value for `expansions` that we pass is `author_id`. Additionally, we will specify the `user_fields` that we want returned such as profile_image_url etc. Learn more about available fields [here](https://developer.twitter.com/en/docs/twitter-api/fields).
# - From the response, we will get the users list from the `includes` object. Then, we will look up the user information for each Tweet, using the `author_id` of the Tweet.
# - Python code example:
#
# ```python
# # Replace with your own search query
# query = 'covid -is:retweet'
#
# tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'],
#                                      user_fields=['profile_image_url'], expansions='author_id', max_results=100)
#
# # Get users list from the includes object
# users = {u["id"]: u for u in tweets.includes['users']}
#
# for tweet in tweets.data:
#     if users[tweet.author_id]:
#         user = users[tweet.author_id]
#         print(user.profile_image_url)
# ```

# %%
query = 'dolar lang:tr'

tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'],
                                     user_fields=['name', 'username', 'verified'], expansions='author_id', max_results=100)

users = {u["id"]: u for u in tweets.includes['users']}

for tweet in tweets.data:
    if users[tweet.author_id]:
        user = users[tweet.author_id]
        print(f"Name: {user.name}\nUsername: {user.username}\nVerified: {user.verified}\nTweet: {tweet.text}\n\n")
# Out:
# Name: ikra
# Username: d_ikranur
# Verified: False
# Tweet: RT @misvakcaps: Everest'e "İmam Hatipler Kapatılsın" yazmak için tırmanırken fenalaşan Merve Bakdur gözünü hastanede açtı.
#
# 7500 dolar heli…
#
#
# Name: Yağmur Poyraz
# Username: demrengi
# Verified: False
# Tweet: RT @milyonerzihin: Bugün $HIVE fiyat 1.18'e gelmiş ama kimse gönderinin altına gelipte bi teşekkür etmemiş.
# Yükselirken böyle arkadaşlar.…
#
#
# Name: Hüseyin AY
# Username: husseyinay
# Verified: False
# Tweet: RT @esilayanefesol: Siz hiç "ölmemek için" aç kaldınızmı?
#
# Kerimcan #fenerinmacivar
# #Fenerbahce #LiSA #Dolar #KaymakamMiraçBiziz https://t.…
#
#
# Name: Sosyal FX Haber
# Username: sosyalfx
# Verified: False
# Tweet: 🇺🇸 ABD İşsizlik Oranı (Ekim)
#
# Açıklanan: 4,6%
# Beklenti: 4,7%
# Önceki: 4,8%
#
# #dolar https://t.co/BVRZflWn9Q
#
#
# Name: seyyah
# Username: illegal_gezgn06
# Verified: False
# Tweet: RT @sagdanhaber: Everest’e tırmanırken fenalaşan Merve Bakdur, Katmandu'da gözünü açtığında helikopter masrafı olarak 7 bin 500 dolar borçl…
#
#
# Name: Rıdvan Baştürk
# Username: ridvanbasturk
# Verified: True
# Tweet: ABD istihdam verileri ateş etti...
#
# Dolar endeksine güvenenler burada mı 😎
#
#
# Name: GANNMarkets TR
# Username: gannmarketstr
# Verified: False
# Tweet: 🇺🇸 ABD, Tarım Dışı İstihdam (Eki) Verisi!
#
# 👉 312K olan veri,
#
# 🔴 531K olarak açıklandı.
#
# 🌐 Fırsatlardan şimdi yararlanın; https://t.co/irCpgLoE4v
#
# #abd #dolar #altın #cuma https://t.co/6wujGf956c
#
#
# Name: Abdulkadir Kesik
# Username: abdulkadirksk
# Verified: False
# Tweet: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :)
#
#
# Name: ...🔺
# Username: Manifesto______
# Verified: False
# Tweet: RT @Matsuda_Rem: $Roco Yüzde 39 Apr oranıyla dolaşımdaki arzın yüzde 50 si stake edilmiş durumda şuan. Topluluğun ekibe ve çalışmalarına ne…
#
#
# Name: Aragorn
# Username: zzyyy25
# Verified: False
# Tweet: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :)
#
#
# Name: Servet Polat
# Username: spolatRT
# Verified: False
# Tweet: RT @Kervan_Reisen: Everest’e tırmanırken fenalaşan Merve Bakdur, Katmandu'da gözünü açtığında helikopter masrafı olarak 7️⃣5️⃣0️⃣0️⃣ 💵 dola…
#
#
# Name: Nuray Şahinoğlu
# Username: nuray_sahinoglu
# Verified: False
# Tweet: RT @ilhan_karasu: 1 milyar dolar #tether basım zamanlarını hatırlıyorum 100k habercisi .
#
#
# Name: Sosyal FX Haber
# Username: sosyalfx
# Verified: False
# Tweet: 🇺🇸 ABD Tarım Dışı İstihdam (Ekim)
#
# Açıklanan: 531K
# Beklenti: 450K
# Önceki: 312K
#
# #dolar https://t.co/5CzimuUXgF
#
#
# Name: Hedef Capital
# Username: HedefCapital
# Verified: False
# Tweet: 🇺🇸 ABD Tarım Dışı İstihdam (Ekim)
#
# #dolar #eurusd https://t.co/qWeBdQF8oO
#
#
# Name: Lotas Capital
# Username: lotascapital
# Verified: False
# Tweet: 🇬🇧 ABD - Tarım Dışı İstihdam (Eki) Verileri Açıklandı!
#
# 🟩Önceki: 312K
#
# ✴️Açıklanan: 531K
#
# 🌐Dünya piyasalarında Lotas Capital ile yer edinin!
#
# 🔐LOTAS CAPITAL
#
# #USDT #usdtry  #dolar  #CUMA https://t.co/DbccB6SAWR
#
#
# Name: Satoshi Nakamoto'nun Ruhu
# Username: YunusEmreBAL1
# Verified: False
# Tweet: Ben buradan bir miktar kâr realize ettim. 57 dolar bölgesi oldukça önemli bir direnç. https://t.co/AGKrPdGfy1
#
#
# Name: Prof. Dr. Mehmet Emin Birpınar
# Username: Mbirpinar
# Verified: True
# Tweet: ABD İklim Özel Temsilcisi Kerry: Gelişmekte olan ülkelere yıllık 100 milyar dolar fon hedefine 2022'de ulaşabiliriz - BBC News Türkçe https://t.co/AVaZNE7pRv
#
#
# Name: Ata Çığır
# Username: Atamcgr
# Verified: False
# Tweet: RT @RtradeCn: Bu hafta da 100 dolar verelim takipçilerimize.💵
# Hemen hemen her hafta yaparız demiştik🧿
# RT ve Beğeni yapanlardan 2 kişiye ben…
#
#
# Name: NS1905💛❤️
# Username: natigselim
# Verified: False
# Tweet: @gszinciri Fotografdakinden daha rahat pozisyondu onu soyliim bi kere. Topa bas sola ver bu kadar. Maalesef Momo bunu bile dusunemeyecek kafada bir futbolcu. Momo-dan bize forvet falan olmaz. Evet belirlo yetenekleri var ama 4 milyon dolar verilmez
#
#
# Name: çarli
# Username: lis9296
# Verified: False
# Tweet: RT @tolgaozcelkk909: SKANDAL!!!
#  Pfizer'den Çocuklarda Aşılanmayı Teşvik Eden Doktora 2 Milyon Dolar Ödendi!
# https://t.co/aDqnUL5rD3
#
#
# Name: Mehmet Sisman
# Username: mehmetsismann
# Verified: False
# Tweet: Dolar uzerinden memlekette aclik ve sefalet var diyen Muhalefetin sozde Milliyetci ve Ulusalcilari Basak Hanimi duydunuz mu ?
#
# “Kocasi olan Teror destekcisi  Selahattin hapse atildiginda dolar 3    Bugun 9.7 mis !!!
#
# @hdpdemirtas
# @meral_aksener
# @kilicdarogluk https://t.co/pMkC3IX5ts
#
#
# Name: mehmet dogan
# Username: Mehmetsamet125
# Verified: False
# Tweet: RT @VatandasTube: İki vatandaş arasında 128 milyar dolar tartışması üzerinden yumruk yumruğa kavga çıktı. Via/@Zeyrek_00
# #BirŞeylerOlduGerç…
#
#
# Name: İsmail Şayan
# Username: is_xs
# Verified: False
# Tweet: River Plate'in Adidas ile sponsorluk sözleşmesi.
# 6 yılda 31 milyon dolar garanti edilmiş(9,1'i peşin).
# Libertadores şampiyonluğu'nun 1m $, Lig şampiyonluğunun 0,75m $, Sudamericana şampiyonluğunun 0,5m $, Arjantin Kupası'nın 0,2m $  bonusu var.
# Satışlardan da tutara göre pay var. https://t.co/9fTyfn2Lvl
#
#
# Name: TruvaFX
# Username: truvafx1
# Verified: False
# Tweet: 🇺🇸 AMERİKA - Tarım Dışı İstihdam (Eki)
#
# #PMI #ISM #ekonomiktakvim #forexsignals #forextrader #forextrading #forexmarket #forexlifestyle #FOREXTECHT #forexsignal #dolar #usdtry #GBPJPY #GBP #USDCAD #truvafx https://t.co/Y3uSGvmcGu
#
#
# Name: kübroşkom
# Username: zynpkubraaa
# Verified: False
# Tweet: RT @murselkanatoglu: Küreselciler de çok iyi biliyor ki Türkiye'de kendilerine kök söktüren kişi Berat Albayrak'tır
# Ülke'nin parasını gizli…
#
#
# Name: Habip
# Username: ortakoylu19
# Verified: False
# Tweet: @abdullahciftcib Anlamı yeniden tedbir. Zaten kırılmış tedarik zincirini iyice parçalamak. Şu anda Temel gıda stoklamak dolar, altın stoklamaktan daha iyi. Bunu hane bazında değil devlet olarak yapmalıyız.
#
#
# Name: Osman Özmen
# Username: Osmanzmen16
# Verified: False
# Tweet: RT @RefahHilvan: Maliye Bakanı "Doğalgazı 100'e alıp vatandaşa 25 birime satıyoruz" demiş büyük bir jestmiş gibi.
# Eğer TL bu kadar değer k…
#
#
# Name: SİMURG TAKORAN COİN
# Username: simurg_takoran
# Verified: False
# Tweet: RT @borsaparatic: Binance'dan USDT lerinizi dışarı çıkarıp gerçek dolar yaparken minimum efor ve sıfır kayıpla nasıl yapacağınızı anlatacağ…
#
#
# Name: erkanozcan
# Username: erkanozcantwit
# Verified: False
# Tweet: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :)
#
#
# Name: Yilmaz Karakas
# Username: YlmzKrks
# Verified: False
# Tweet: ABD hazinesinin Ekim 2020’de ihrac ettigi 100 dolarlik bono/tahvil’in bugunku reel degeri 95 dolar.
#
# Diger gelismis ulkelerde de durum ayni.
#
# Diger yandan kamu borcu/gdp tarihi yuksek seviyelerde.
#
# Fed’in yakin donemde enflasyonla mucadele edecegini saniyorsaniz, bol sanslar. https://t.co/epPQHhZ8YL
#
#
# Name: Primeverse
# Username: prime_chain
# Verified: False
# Tweet: Kripto fenomenleri takip edin ama asla onlarla birlikte işleme girmeyin. Asla "araştırdım beğendim" tarzında reklam aldığını belirtmeden reklam yapanlara 100 dolar daha çok kazanmak için sizinle oynayanlara prim vermeyin. Neredeyse hiçbiri sandığınız gibi para ile oynamıyor.
#
#
# Name: Ömer
# Username: Omerhamza1982
# Verified: False
# Tweet: RT @yillar_kayip: Emniyet müdürü bir arkadaş vardı eşi parasızlıktan dolayı 5 ayda bir geliyordu.😔 garibim içine ata ata midesi bitmişti  n…
#
#
# Name: Kenan Bulut
# Username: PrfdrKnnblt
# Verified: False
# Tweet: @GolgeSessiz #BizeALLAHyeter ne ekonomi ne dolar umurumuzda değil. Elhamdülillah. Maşallah hak yolu
#
#
# Name: moon
# Username: scarletmoonH
# Verified: False
# Tweet: RT @sefikdiyin: Bu saatten sonra beni mutlu edebilecek tek şey; benden habersiz hesabıma yatırılan 2 milyon dolar
#
#
# Name: Aydın EYT li
# Username: Aydnl11631645
# Verified: False
# Tweet: RT @Seyfett39479898: Başkanlık sistemi gelirse,
# Türkiye uçacak dediler,
# Evet,türkiye uçtu,
# Ama zenginliğe deyil,yoksulluga  uçtu.
#
# Hak,adal…
#
#
# Name: Dolar Kuru💰
# Username: canlidolarkuru
# Verified: False
# Tweet: 15:30⏱
# 𝑫𝒐𝒍𝒂𝒓 𝑲𝒖𝒓𝒖 💵
# ₺9.6945
# 0.05%🔺
# 05-11-2021 15:30
# #USDTRY #dolar #MeralAbla
#
#
# Name: ☾★☾★☾★#TCBOZKURTVATANϜΎϞᏥ♦KIZILELMA🍎TURAN☾★M.Ö220
# Username: tcbozkurtvatan
# Verified: False
# Tweet: RT @OpDrBilgehan: Katil Korona aşıları işledikleri suçlar üzerinde bıraktıkları parmak izlerini silmek için yüz milyonlarca dolar harcamaya…
#
#
# Name: Amigdala🌑🦉
# Username: Gagagala3
# Verified: False
# Tweet: RT @RtradeCn: Bu hafta da 100 dolar verelim takipçilerimize.💵
# Hemen hemen her hafta yaparız demiştik🧿
# RT ve Beğeni yapanlardan 2 kişiye ben…
#
#
# Name: İdeal Data Alert
# Username: iDealBilgi
# Verified: False
# Tweet: *TCMB Kapanış Kurları: Dolar 9,7000 / 9,7175 TL, Euro 11,1995 / 11,2197 TL, Euro/Dolar 1,1546
#
# #iDeal
#
#
# Name: Güncel Döviz Kurları
# Username: dovizbilgisi
# Verified: False
# Tweet: Dolar: 9.7219
# Euro: 11.1972
# Altın Ons: $1792
# Gram Altın: 559,83
# Gümüş: 7,43
# Sterlin: 13.0761
# Güncellenme Zamanı: 15:29:58
# Anlık Döviz&amp;Altın Fiyatları Uygulaması(Android): https://t.co/eue7QXaADo
# #dolar #euro #altın
#
#
# Name: T24
# Username: t24comtr
# Verified: True
# Tweet: ABD İklim Özel Temsilcisi Kerry: Gelişmekte olan ülkelere yıllık 100 milyar dolar fon hedefine 2022'de ulaşabiliriz
# https://t.co/zdVi5VUEL6
#
#
# Name: REALİST
# Username: SlhttnFdl
# Verified: False
# Tweet: @Vforrkripto ICP candır hedefim 350 dolar maliyetim 38 dolar
#
#
# Name: sinem ka
# Username: dalgageciyosun
# Verified: False
# Tweet: Dolar alın https://t.co/qAqhhPNi8K
#
#
# Name: Bilge KARACA
# Username: Bilge61
# Verified: False
# Tweet: RT @EremSenturk: Bak ben demiyorum Başak Hanım diyor: PKK destekçisi küresel sistem başta Selahattin Demirtaş ve arkadaşlarının terörle müc…
#
#
# Name: Nimetullah Şıltak
# Username: 63nimetullah
# Verified: False
# Tweet: RT @RefahHilvan: Maliye Bakanı "Doğalgazı 100'e alıp vatandaşa 25 birime satıyoruz" demiş büyük bir jestmiş gibi.
# Eğer TL bu kadar değer k…
#
#
# Name: Canpolat
# Username: CanpolatErbil3
# Verified: False
# Tweet: RT @solcugazete: New York Belediyesi, aşı olan 5-11 yaş arasındaki çocuklara 100 dolar hediye edecek
#
#
# Name: enkayenerji ,Maske tak , Aşı ol , Doğaya git
# Username: enkayenerji
# Verified: False
# Tweet: RT @aa_finans: 🔸Petrol projeleri için uzun vadeli borçlanma maliyetleri yenilenebilir enerji yatırımlarına göre, yüzde 20 daha yüksek hale…
#
#
# Name: gokhanozkan742
# Username: gokhanozkan742
# Verified: False
# Tweet: RT @___ARSLAN___66: Cumhurbaşkanımız  EYT,yi çıkarsa hepsini emekli etse 4000 TL aylık verse
# Asgari ücret 7500 TL olsa
# Dolar tedavülden ka…
#
#
# Name: Semih
# Username: retrosemih
# Verified: False
# Tweet: RT @tarihvesehir: 1980 yapımı 'Tanrılar Çıldırmış Olmalı' filmi 60 milyon dolar hasılat yapmıştır. Başrolde oynayan siyahi oyuncu ise 300 d…
#
#
# Name: Akgün KATMAN
# Username: AkgunKatman
# Verified: False
# Tweet: RT @borsaparatic: Binance'dan USDT lerinizi dışarı çıkarıp gerçek dolar yaparken minimum efor ve sıfır kayıpla nasıl yapacağınızı anlatacağ…
#
#
# Name: Recep Odabaş
# Username: RecepOdaba18
# Verified: False
# Tweet: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :)
#
#
# Name: tansu çetiner
# Username: cetiner_tansu
# Verified: False
# Tweet: RT @kiyaslayan: 🌐 Dünyada Petrol Varil Fiyatları
#
# ▪️1 Yıl önce 43,4 dolar
# ▪️Bugün 82,5 dolar
# 🔼 Artış % 90
#
# 🇹🇷 Türkiye'de Benzin Pompa Fiyat…
#
#
# Name: Sezen Şafak
# Username: SezenSafak
# Verified: False
# Tweet: RT @tele1comtr: ➤Dolar haftaya yeni rekorla başladı: 10 lirayı zorluyor
# ➤Abdullah Gül sessizliğini bozdu: Gündeme ilişkin neler söyledi?
# ➤İ…
#
#
# Name: Batuhan Duranlar
# Username: batudrnlr
# Verified: False
# Tweet: @Dramatoryum Bunu DDR4 sistemim varken duymak acı verici, hele ki bu dolar kurunda.
#
#
# Name: hatice balbaba #Ak#
# Username: haticeakbenbalb
# Verified: False
# Tweet: RT @FUATUGUR: “Dolar kocamı hapse attığınız için arttı” diyor kısaca. Biliyoruz bunu.Küresel finans çeteleri sadece kocan değil,içerdeki pe…
#
#
# Name: Sezen Şafak
# Username: SezenSafak
# Verified: False
# Tweet: RT @sozcumuratoglu: "10 ülkenin büyükelçisini" ülkede istemediğimizi açıklayınca olumsuz olarak algılanıp dolar artıyorsa⬆️
#
# Buna "gerek ka…
#
#
# Name: ErcAn ErdOğdU
# Username: mutimar
# Verified: False
# Tweet: Birazdan TDI verisi gelecek...
#
# Dolar/TL Short poz açıyorum
# Euro/Usd Long poz açıyorum
#
# #parite #Dolar #euro #usdtry
#
# Asla yazdıklarım yatırım tavsiyesi değildir
#
#
# Name: Kusgibi
# Username: Kusgibi3
# Verified: False
# Tweet: RT @LeventUzumcu: Ötekileştirile ötekileştire dolar milyarderi olmuş bir çocuk.
#
#
# Name: Algoritmikfilozof
# Username: Algoritmikfilo2
# Verified: False
# Tweet: RT @freemind1923: Hepsini geçtim ordunun tepesine atadıkları Fetöcü subaylar darbeye kalkıp 250 insanı öldürdü, ekonomiye milyarlarca dolar…
#
#
# Name: KESKİN3581#KIZILCIKSOPASI #ANDIMIZ
# Username: keskin3581
# Verified: False
# Tweet: RT @serdardirican: Bir kenera yazın.
# PCR pozitif çıkan herkese bu Molnupiraviri dayayacaklar.
# Pahalı bir ilaç (kutusu 700 dolar)
# SGK'nın…
#
#
# Name: cengiz uzun
# Username: cengizuzun15
# Verified: False
# Tweet: RT @t_oncu: Para konusuyla ilgilenen arkadaşlara soru. Parayı bankacılık sistemi kredi vererek ve varlık alarak yarattığına göre, küresel b…
#
#
# Name: Özgür Düşün! ⚡️
# Username: freemind1923
# Verified: False
# Tweet: @YolTV Hepsini geçtim ordunun tepesine atadıkları Fetöcü subaylar darbeye kalkıp 250 insanı öldürdü, ekonomiye milyarlarca dolar zarar verdi ve hiç utanmadan sıkılmadan bunu diyor.. diyebiliyor
#
#
# Name: Air WhitelisT
# Username: Air_Whitelist
# Verified: False
# Tweet: Mexc Borsasında Hesap açan herkese 200 Dolar Bonus Hediye Duyuru yeni yapıldı.
# Binance'nın yerını alacak bır Borsa platformu kayıt olup 200 doları alabılırsınız .
#
# https://t.co/jAgLOO1Wq9
#
# #Gaia #MEXC #BTC #Binance #Airdrop https://t.co/gHIFoRwejR
#
#
# Name: Orhan SARIKAYA 🇹🇷
# Username: osarikaya01
# Verified: False
# Tweet: ABD Dışişleri Bakanlığı Suudi Arabistan'a 640 milyon dolar değerinde 280 adet AIM-120C tipi Orta Menzilli Havadan Havaya Füze'nin satışına onay verdi.
#
# ABD Dışişleri Bakanlığı, söz konusu füzelerin Yemen'den yapılan hava saldırılarına yönelik savunma amaçlı olduğunu belirtti. https://t.co/qmaZFQmmkD
#
#
# Name: Fatih Tuncel
# Username: FatihTu31287333
# Verified: False
# Tweet: @ozguradamTurk Dolar 2 tl ye inerse bu rakam bile yeterli ama zamlar devam ederse 10000 olsa ne olur
#
#
# Name: Egecan Çitim
# Username: egcnctm
# Verified: False
# Tweet: @celikciyan Kardeşim önüne binlerce dolar koysalar donunu bile satarsın nft olarak...
#
#
# Name: Ayse Kadioglu
# Username: AyseKadioglu2
# Verified: False
# Tweet: RT @1923nb: İki vatandaş arasında 128 milyar dolar tartışması üzerinden yumruk yumruğa kavga çıktı.Belli kesimi ikna edemezsiniz onlar her…
#
#
# Name: Merto
# Username: regulusnemean
# Verified: False
# Tweet: RT @tolgaozcelkk909: New York Şehri belediye başkanı
# Bill de Blasio
# 11 ila 5 yaş arasındaki çocuklara Covid-19 aşısı yaptıran ailelere  1…
#
#
# Name: mustafaozdil
# Username: GKmusti06
# Verified: False
# Tweet: RT @dw_turkce: "Cengiz, Kolin ya da Limak devletle sözleşmesini Dolar'la, Euro'yla yapıyor. Hiçbir kaybı yok. TL ile yapan Ahmet'in, Ayşe'n…
#
#
# Name: Ali Aslan Güncü
# Username: Gncalii
# Verified: False
# Tweet: @savasim80 Hocam Hoşgeldiniz :)
# #dolar 10.40 seviyesi teknik beklenti. :) https://t.co/azdyJE6DFK
#
#
# Name: Özgür Düşün! ⚡️
# Username: freemind1923
# Verified: False
# Tweet: Hepsini geçtim ordunun tepesine atadıkları Fetöcü subaylar darbeye kalkıp 250 insanı öldürdü, ekonomiye milyarlarca dolar zarar verdi ve hiç utanmadan bunu diyor.. diyebiliyor.. https://t.co/78X9Te65gR
#
#
# Name: 洪嘉進 Hong Jiajin
# Username: Jj553399Twbook
# Verified: False
# Tweet: RT @rockn4you: "Uyan artık uyan
# Uyan dostum uyan
# Uyan artık uyan karanlık uykundan."
#
# Dolar 9.74
#  https://t.co/lDfTTQkMPq
#
#
# Name: tansu çetiner
# Username: cetiner_tansu
# Verified: False
# Tweet: RT @kiyaslayan: Türkiye'nin altın rezervi;
#
# ▪️2010: 4.5 milyar dolar
# ▪️2020: 42 milyar dolar
#
# Altın rezervini artırmak için harcanan para k…
#
#
# Name: Kaan
# Username: KaanArs32895679
# Verified: False
# Tweet: RT @ilhangunes58: #BülentEcevit Medine’deki 110 dönümlük  dedesinden kalan araziyi Türk hacılar rahat etsin diye ,Diyanete bağışlamıştı . D…
#
#
# Name: Doğasever
# Username: DogaSeverTR
# Verified: False
# Tweet: @oguzturkannn @Grkemaalkolu @LaikLaikoglu Aynen aynen imkansız değil. 1 sene içinde 54 küsür milyon dolar yapıyor. Nerenin cahilisiniz arkadaş siz 🤣🤣🤣🤣🤣🤣🤣
#
#
# Name: orhan
# Username: sadecesex3456
# Verified: False
# Tweet: @Reef_Turkey #reef 1 dolar 💵 olur mu
#
#
# Name: The Supterio %9.8ML
# Username: supterioistakeN
# Verified: False
# Tweet: RT @sefikdiyin: Bu saatten sonra beni mutlu edebilecek tek şey; benden habersiz hesabıma yatırılan 2 milyon dolar
#
#
# Name: Melisa Şahin
# Username: Mlisasahin
# Verified: False
# Tweet: RT @_CengizGocer: T24'ün verdiği habere göre, kulislerde ekonominin başına yeniden Berat Albayrak'ın geçeceği iddiaları varmış.
#
# Geçmiş ols…
#
#
# Name: gokhanozkan742
# Username: gokhanozkan742
# Verified: False
# Tweet: RT @murselkanatoglu: Küreselciler de çok iyi biliyor ki Türkiye'de kendilerine kök söktüren kişi Berat Albayrak'tır
# Ülke'nin parasını gizli…
#
#
# Name: Kawa Traders
# Username: traders_kawa
# Verified: False
# Tweet: Başka bir hesabımdan sıraya girerek girdiğim $IMX bana 200 $ alım hakkı çıkmış 😁😎 Diğer hesaptan keşke usdt olarak katılım sağlasaydım :) En az 1 dolar bekliyorum. https://t.co/RUveNjEMWH https://t.co/JabcdvRSQY
#
#
# Name: uğur
# Username: caydanlik59
# Verified: False
# Tweet: RT @deryabuyukuncu: Ali Erbaş: “Diyanet, halkın en çok güvendiği ve sahiplendiği kurum.”
#
# Katılıyorum ama gülmekten.😂
#
# #TakunyalıFührer #Di…
#
#
# Name: Ahmed🇹🇷RT__1453
# Username: Ahmed__1453
# Verified: False
# Tweet: RT @murselkanatoglu: Küreselciler de çok iyi biliyor ki Türkiye'de kendilerine kök söktüren kişi Berat Albayrak'tır
# Ülke'nin parasını gizli…
#
#
# Name: BettingCulture1903
# Username: sportsclub1903
# Verified: False
# Tweet: RT @CryptoHunterTR: Üstteki sabit tweeti RT eden arkadaşlarım arasından rastgele seçeceğim 2 arkadaşıma 100'er dolar hediye edeceğim :)
#
#
# Name: Özer Yiğenli
# Username: yigenli_ozer
# Verified: False
# Tweet: RT @___ARSLAN___66: Cumhurbaşkanımız  EYT,yi çıkarsa hepsini emekli etse 4000 TL aylık verse
# Asgari ücret 7500 TL olsa
# Dolar tedavülden ka…
#
#
# Name: Ahmed🇹🇷RT__1453
# Username: Ahmed__1453
# Verified: False
# Tweet: RT @___ARSLAN___66: Cumhurbaşkanımız  EYT,yi çıkarsa hepsini emekli etse 4000 TL aylık verse
# Asgari ücret 7500 TL olsa
# Dolar tedavülden ka…
#
#
# Name: Ningabluee™
# Username: Ningabluee
# Verified: False
# Tweet: @atabenli olsun olsun tüyo verirse tam tersini yapar dolar alırız belki afadfsdgsfg
#
#
# Name: Erdal Akkaya
# Username: ErdalAk15871248
# Verified: False
# Tweet: RT @esilayanefesol: Siz hiç "ölmemek için" aç kaldınızmı?
#
# Kerimcan #fenerinmacivar
# #Fenerbahce #LiSA #Dolar #KaymakamMiraçBiziz https://t.…
#
#
# Name: tansu çetiner
# Username: cetiner_tansu
# Verified: False
# Tweet: RT @kiyaslayan: 👉Türkiye'nin Afrika kıtasıyla ticareti;
#
# ▪️2002: 4,3 milyar dolar
#
# ▪️2020: 22 milyar dolar
#
# 👉Kıtadaki ticari temsilcilik sa…
#
#
# Name: borsagundem
# Username: borsagundem
# Verified: False
# Tweet: Gelişmekte olan piyasalarda gerilim artıyor #enflasyon #dolar #FED #borsa #hisse - https://t.co/J2k9lF59kM https://t.co/UriaCjng6H
#
#
# Name: Muhammet DEMİR
# Username: mhmmt_dmir
# Verified: False
# Tweet: RT @CryptoBulls34: $EOS
#
# Eos tarafında 4 dolar civarı trend dip seviyemizdir. Altında hafta kapanışı stoploss olmak kaydı ile bu şekilde iz…
#
#
# Name: Süleyman
# Username: Slymnn2000
# Verified: False
# Tweet: RT @RtradeCn: Bu hafta da 100 dolar verelim takipçilerimize.💵
# Hemen hemen her hafta yaparız demiştik🧿
# RT ve Beğeni yapanlardan 2 kişiye ben…
#
#
# Name: muafiyet
# Username: zaferost
# Verified: False
# Tweet: Gerer Yayını Sertçe
# Düşmanı Vurur Mertçe
#
# O cengiz Duruşu
# Turan'ın Kuruluşu
#
# duamız kabul olsun
# 360 milyar dolar bulunsun.
#
# türkiye kurtulsun.
# 4 milyon kiracı ve işsiz kurtulsun
#
# molla muzaffer iktidar olsun
#
#
# Name: Kubilay🇹🇷44🇹🇷
# Username: Kubilaykdrh
# Verified: False
# Tweet: @Fatmacn0 1 milyar dolar için lüksemburg'tan dileniyorduk
#
#
# Name: HİMERA____ 695
# Username: Himera___695
# Verified: False
# Tweet: Everest'e "İmam Hatipler Kapatılsın" yazmak için
#  tırmanırken fenalaşan
# Merve Bakdur
#  gözünü hastanede açtı.
#
# 7500 dolar helikopter parasını ödeyemeyince rehin alındığı hastaneden İmamhatipli Cumhurbaşkanı'nın
#  talimatıyla kurtarıldı.
#
# KIŞ  KIŞ  ZİLLET https://t.co/HWbKhwluAl
#
#
# Name: Temmuz Doğruyol
# Username: temmuzdogruyol
# Verified: False
# Tweet: @ProfDemirtas hocam dolma kalem çok yakar dolar 9 lira. kurşun daha iyi bi yatırım olur
#
#
# Name: Diyap Kömürcüoğlu
# Username: DiyapKmrcolu1
# Verified: False
# Tweet: RT @1881Erdem: #BNB de kalkışma varmış gelsin bakalım en son En tepede verdik 688 .88 alanda kazansın dedik ama alan battı 225 dolar geldi.…
#
#
# Name: sermest
# Username: mstfffffffff
# Verified: False
# Tweet: RT @Darkwebhaber: Japonya’da hükümet, 18 yaşın altındaki tüm gençlere ailelerinin maddi durumuna bakılmaksızın ekonomiyi canlandırmak amacı…
#
#
# Name: Madi Tau
# Username: ergoerr
# Verified: False
# Tweet: RT @1923nb: İki vatandaş arasında 128 milyar dolar tartışması üzerinden yumruk yumruğa kavga çıktı.Belli kesimi ikna edemezsiniz onlar her…
#
#
# Name: Yağız
# Username: Yagiz_5834
# Verified: False
# Tweet: RT @el_patrone_bist: size #dolar #xu100 korelasyonunu göstereyim
#
# eğer dolar 1.resimde ki yerden aşağı gelir
#
# eğer #XU100  2.resimde ki yer…
#
#
# Name: some.one
# Username: someone55757683
# Verified: False
# Tweet: RT @venusoz34: Kendimi cok seviyorum! 🪱 vnsoz45@gmail.com 💌
#
# #tekkadın #istanbulbayan #Dolar #Bitcoin #Binance #btc #finans #Dubai #Qatar #…

# %% [markdown]
# ## 7. Getting Tweets with media information, for each Tweet
#
# - In this example, we want media information, which is why the value for `expansions` that we pass is `attachments.media_keys`.
# - Additionally, we will specify the `media_fields` that we want returned such as preview_image_url etc. Learn more about available fields [here](https://developer.twitter.com/en/docs/twitter-api/fields).
# - From the response, we will get the media list from the `includes` object. Then, we will look up the media information for each Tweet, using the `media_keys` from the attachements for the Tweet.
# - Python code example:
#
# ```python
# client = tweepy.Client(bearer_token='REPLACE_ME')
#
# # Replace with your own search query
# query = 'covid -is:retweet has:media'
#
# tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'],
#                                      media_fields=['preview_image_url'], expansions='attachments.media_keys',
#                                      max_results=100)
#
# # Get list of media from the includes object
# media = {m["media_key"]: m for m in tweets.includes['media']}
#
# for tweet in tweets.data:
#     attachments = tweet.data['attachments']
#     media_keys = attachments['media_keys']
#     print(tweet.text)
#     if media[media_keys[0]].preview_image_url:
#         print(media[media_keys[0]].preview_image_url)
# ```

# %%
client = tweepy.Client(bearer_token=bearer_token)

query = 'covid -is:retweet has:media'

tweets = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'],
                                     media_fields=['preview_image_url'], expansions='attachments.media_keys',
                                     max_results=100)

media = {m["media_key"]: m for m in tweets.includes['media']}

for tweet in tweets.data:
    attachments = tweet.data['attachments']
    media_keys = attachments['media_keys']
    print(tweet.text)
    if media[media_keys[0]].preview_image_url:
        print(media[media_keys[0]].preview_image_url)
# Out:
# For the second year in a row, Spotify remains #1 in the Apps &amp; social platforms industry. It also ranks #1 among men, women and millennials. Find more about brand here: https://t.co/3ebXcmwl7H https://t.co/hJBHiGbQWW
# В Україні недовиявлення випадків туберкульозу через #COVID19 – ЦГЗ
#
# https://t.co/IeNePJkeNs https://t.co/HgqdkOAtGt
# Santos retoma vacinação contra a Covid-19 em três locais e cidade volta a contar com 18 postos 💉 https://t.co/qbjXQbhIc6 #g1 https://t.co/sFAlwzO0Fy
# 📢If you're ✅age 50+ ✅health &amp; social care worker ✅clinically vulnerable you can have a #CovidBooster if your 2nd vaccine was 6 MONTHS AGO or more. Your GP will be in touch OR Book here : https://t.co/rUhoVnVCD7
# *NB no walk-in booster clinics currently available in Rochdale* https://t.co/TkJOJ1ILfA
# Come si può muovere il lavoratore in possesso di #GreenPass, rilasciato dopo la guarigione dal #COVID-19, in scadenza e in attesa della comunicazione dell' #AUSL con la data per la #vaccinazione? 😷
#
# Ecco la risposta dei nostri esperti ⬇
#
# https://t.co/rt6xKPYGbG https://t.co/e58lFNu2hr
# #Pfizer asegura que su píldora reduce casi un 90 % el riesgo de muerte por #Covid_19
#
# https://t.co/keXPTpYxlU https://t.co/HXyMADMwis
# Movimiento Ciudadano propone recortar presupuesto a revocación de mandato y destinarlo a vacunas contra COVID-19 https://t.co/WW922f6CiP https://t.co/BQdj4BVFzD
# Good morning Sudbury and districts! Here are the #COVID19 #vaccination opportunities being offered today.
#
# 📅 Friday, November 5
#
# 📍 Pop-up clinic
# • Dr. Edgar Leclair Community Centre and Arena, 158 St. Agnes St, Azilda, 9 a.m. to 3 p.m.
#
# https://t.co/PFz1CDXsJV #COVID19 https://t.co/iSDPtMSYdm

# %% [markdown]
# ## 8. Searching for geo-tagged Tweets
#
# - Some Tweets have geographic information associated with them. The search endpoints in the Twitter API v2 support operators such as `place`, `place_country`, `bounding_box`, `point_radius` etc. (these operators are currently only available in the **academic research product track**) that allow you to get these geo-tagged Tweets.
# - In the example below, we want all Tweets that are from the country `US`, which is why we specify it in our search query using the `place_country:US` operator.
# - Now because by default, only the Tweet ID and Tweet text are returned, we have to specify the fact that we want the geo information in our response as well.
#     - We do this by passing the `expansions='geo.place_id'` to the `search_all_tweets` function and we also specify the geo fields that we are looking for using `place_fields=['place_type','geo']`.
# - In our response, we get the list of places from the `includes` object, and we match on the `place_id` to get the relevant geo information associated with the Tweet (the `place.full_name` in the example below).
# - Python code example:
#
# ```python
# client = tweepy.Client(bearer_token='REPLACE_ME')
#
# # Replace with your own search query
# query = 'covid -is:retweet place_country:US'
#
# tweets = client.search_all_tweets(query=query, tweet_fields=['context_annotations', 'created_at', 'geo'],
#                                   place_fields=['place_type', 'geo'], expansions='geo.place_id', max_results=100)
#
# # Get list of places from includes object
# places = {p["id"]: p for p in tweets.includes['places']}
#
# for tweet in tweets.data:
#     print(tweet.id)
#     print(tweet.text)
#     if places[tweet.geo['place_id']]:
#         place = places[tweet.geo['place_id']]
#         print(place.full_name)
# ```

# %% [markdown]
# ## 9. Getting Tweet counts (volume) for a search query
#
# - If you want to get the count of Tweets (volume) for a search term, you can use the `get_recent_tweets_count` function. You can pass it the search `query` and specify the `granularity` for the data aggregation e.g. if you want the daily count, hourly count or 15-minute count for a search term.
# - Python code example:
#
# ```python
# client = tweepy.Client(bearer_token='REPLACE_ME')
#
# # Replace with your own search query
# query = 'covid -is:retweet'
#
# counts = client.get_recent_tweets_count(query=query, granularity='day')
#
# for count in counts.data:
#     print(count)
# ```

# %%
client = tweepy.Client(bearer_token=bearer_token)

query = 'dolar lang:tr -is:retweet'

counts = client.get_recent_tweets_count(query=query, granularity='hour',
                                        start_time='2021-11-01T23:59:59Z', end_time='2021-11-03T23:59:59Z')

for count in counts.data:
    print(count)
# Out:
# {'end': '2021-11-02T00:00:00.000Z', 'start': '2021-11-01T23:59:59.000Z', 'tweet_count': 0}
# {'end': '2021-11-02T01:00:00.000Z', 'start': '2021-11-02T00:00:00.000Z', 'tweet_count': 108}
# {'end': '2021-11-02T02:00:00.000Z', 'start': '2021-11-02T01:00:00.000Z', 'tweet_count': 65}
# {'end': '2021-11-02T03:00:00.000Z', 'start': '2021-11-02T02:00:00.000Z', 'tweet_count': 58}
# {'end': '2021-11-02T04:00:00.000Z', 'start': '2021-11-02T03:00:00.000Z', 'tweet_count': 67}
# {'end': '2021-11-02T05:00:00.000Z', 'start': '2021-11-02T04:00:00.000Z', 'tweet_count': 135}
# {'end': '2021-11-02T06:00:00.000Z', 'start': '2021-11-02T05:00:00.000Z', 'tweet_count': 227}
# {'end': '2021-11-02T07:00:00.000Z', 'start': '2021-11-02T06:00:00.000Z', 'tweet_count': 411}
# {'end': '2021-11-02T08:00:00.000Z', 'start': '2021-11-02T07:00:00.000Z', 'tweet_count': 572}
# {'end': '2021-11-02T09:00:00.000Z', 'start': '2021-11-02T08:00:00.000Z', 'tweet_count': 564}
# {'end': '2021-11-02T10:00:00.000Z', 'start': '2021-11-02T09:00:00.000Z', 'tweet_count': 514}
# {'end': '2021-11-02T11:00:00.000Z', 'start': '2021-11-02T10:00:00.000Z', 'tweet_count': 585}
# {'end': '2021-11-02T12:00:00.000Z', 'start': '2021-11-02T11:00:00.000Z', 'tweet_count': 550}
# {'end': '2021-11-02T13:00:00.000Z', 'start': '2021-11-02T12:00:00.000Z', 'tweet_count': 426}
# {'end': '2021-11-02T14:00:00.000Z', 'start': '2021-11-02T13:00:00.000Z', 'tweet_count': 497}
# {'end': '2021-11-02T15:00:00.000Z', 'start': '2021-11-02T14:00:00.000Z', 'tweet_count': 546}
# {'end': '2021-11-02T16:00:00.000Z', 'start': '2021-11-02T15:00:00.000Z', 'tweet_count': 469}
# {'end': '2021-11-02T17:00:00.000Z', 'start': '2021-11-02T16:00:00.000Z', 'tweet_count': 543}
# {'end': '2021-11-02T18:00:00.000Z', 'start': '2021-11-02T17:00:00.000Z', 'tweet_count': 517}
# {'end': '2021-11-02T19:00:00.000Z', 'start': '2021-11-02T18:00:00.000Z', 'tweet_count': 497}
# {'end': '2021-11-02T20:00:00.000Z', 'start': '2021-11-02T19:00:00.000Z', 'tweet_count': 502}
# {'end': '2021-11-02T21:00:00.000Z', 'start': '2021-11-02T20:00:00.000Z', 'tweet_count': 496}
# {'end': '2021-11-02T22:00:00.000Z', 'start': '2021-11-02T21:00:00.000Z', 'tweet_count': 414}
# {'end': '2021-11-02T23:00:00.000Z', 'start': '2021-11-02T22:00:00.000Z', 'tweet_count': 235}
# {'end': '2021-11-03T00:00:00.000Z', 'start': '2021-11-02T23:00:00.000Z', 'tweet_count': 190}
# {'end': '2021-11-03T01:00:00.000Z', 'start': '2021-11-03T00:00:00.000Z', 'tweet_count': 91}
# {'end': '2021-11-03T02:00:00.000Z', 'start': '2021-11-03T01:00:00.000Z', 'tweet_count': 47}
# {'end': '2021-11-03T03:00:00.000Z', 'start': '2021-11-03T02:00:00.000Z', 'tweet_count': 56}
# {'end': '2021-11-03T04:00:00.000Z', 'start': '2021-11-03T03:00:00.000Z', 'tweet_count': 89}
# {'end': '2021-11-03T05:00:00.000Z', 'start': '2021-11-03T04:00:00.000Z', 'tweet_count': 165}
# {'end': '2021-11-03T06:00:00.000Z', 'start': '2021-11-03T05:00:00.000Z', 'tweet_count': 281}
# {'end': '2021-11-03T07:00:00.000Z', 'start': '2021-11-03T06:00:00.000Z', 'tweet_count': 537}
# {'end': '2021-11-03T08:00:00.000Z', 'start': '2021-11-03T07:00:00.000Z', 'tweet_count': 698}
# {'end': '2021-11-03T09:00:00.000Z', 'start': '2021-11-03T08:00:00.000Z', 'tweet_count': 574}
# {'end': '2021-11-03T10:00:00.000Z', 'start': '2021-11-03T09:00:00.000Z', 'tweet_count': 629}
# {'end': '2021-11-03T11:00:00.000Z', 'start': '2021-11-03T10:00:00.000Z', 'tweet_count': 819}
# {'end': '2021-11-03T12:00:00.000Z', 'start': '2021-11-03T11:00:00.000Z', 'tweet_count': 446}
# {'end': '2021-11-03T13:00:00.000Z', 'start': '2021-11-03T12:00:00.000Z', 'tweet_count': 505}
# {'end': '2021-11-03T14:00:00.000Z', 'start': '2021-11-03T13:00:00.000Z', 'tweet_count': 505}
# {'end': '2021-11-03T15:00:00.000Z', 'start': '2021-11-03T14:00:00.000Z', 'tweet_count': 499}
# {'end': '2021-11-03T16:00:00.000Z', 'start': '2021-11-03T15:00:00.000Z', 'tweet_count': 459}
# {'end': '2021-11-03T17:00:00.000Z', 'start': '2021-11-03T16:00:00.000Z', 'tweet_count': 511}
# {'end': '2021-11-03T18:00:00.000Z', 'start': '2021-11-03T17:00:00.000Z', 'tweet_count': 478}
# {'end': '2021-11-03T19:00:00.000Z', 'start': '2021-11-03T18:00:00.000Z', 'tweet_count': 1024}
# {'end': '2021-11-03T20:00:00.000Z', 'start': '2021-11-03T19:00:00.000Z', 'tweet_count': 801}
# {'end': '2021-11-03T21:00:00.000Z', 'start': '2021-11-03T20:00:00.000Z', 'tweet_count': 526}
# {'end': '2021-11-03T22:00:00.000Z', 'start': '2021-11-03T21:00:00.000Z', 'tweet_count': 436}
# {'end': '2021-11-03T23:00:00.000Z', 'start': '2021-11-03T22:00:00.000Z', 'tweet_count': 275}
# {'end': '2021-11-03T23:59:59.000Z', 'start': '2021-11-03T23:00:00.000Z', 'tweet_count': 147}

# %% [markdown]
# ## 10. Getting a user's timeline
#
# - In order to get the most recent 3200 Tweets from a user's timeline, we can use the `get_users_tweets` method and pass it the user id.
# - We can also specify additional fields that we want using the `tweet_fields` and `expansions` (as shown in the examples above).
# - Python code example:
#
# ```python
# client = tweepy.Client(bearer_token='REPLACE_ME')
#
# # Replace user ID
# id = '2244994945'
#
# tweets = client.get_users_tweets(id=id, tweet_fields=['context_annotations','created_at','geo'])
#
# for tweet in tweets.data:
#     print(tweet)
# ```

# %%
client = tweepy.Client(bearer_token=bearer_token)

id = '2244994945'

tweets = client.get_users_tweets(id=id, tweet_fields=['context_annotations','created_at','geo'])

for tweet in tweets.data:
    print(tweet)
# Out:
# ✋ Lastly, have a hand in the design of the Twitter API v2 with our new open evolution workflow.
#
# https://t.co/i734aV500N
# 🛠️ We continue to build OAuth 2.0 in the open. Thank you to everyone who has built and tested with us so far.
#
# https://t.co/l9JOMVm9Ux
# 📊 If you store large amounts of Twitter data, the new batch compliance endpoints can help you keep your datasets compliant with the Twitter Developer Agreement and Policy.
#
# https://t.co/BQ1EYl9H9u
# 🎧 Build for peace and quiet. The mutes endpoints are now fully available on v2.
#
# https://t.co/Z7PUskP6Ff
# 🚀 Help shape the future of Twitter Spaces with the new Spaces endpoints on the Twitter API v2.
#
# https://t.co/LGeV67ufJZ
# 📃 New v2 manage Lists endpoints help you create more customized, curated, and organized Tweets. Plus, there are brand new endpoints for pinning and unpinning Lists.
#
# https://t.co/VNLNMLewVP
# 🗣️Yesterday we shipped the manage Tweets endpoints. You won't want to miss the new endpoint functionality, only available on v2.
#
# https://t.co/w6Tzb8JlJz
# The year is beginning to wind down, but the Twitter API v2 continues to move forward like never before.
#
# Read on to catch up on the last couple months of progress on the #TwitterAPI 🧵
# https://t.co/Xijy1fcZ64
# Tune in this afternoon at 12:00 PT to hear more about the manage Tweets endpoints.
#
# https://t.co/7MnU6DmOKJ
# You can even generate new revenue streams by Tweeting to Super Followers. Don’t worry, you’ll never have to pay to follow us 😃
# https://t.co/hbvOQ8MOPW

# %% [markdown]
# ## 11. Getting a user's mentions
#
# - In order to get the most recent 3200 mentions for a user, we can use the `get_users_mentions` method and pass it the user id.
# - We can also specify additional fields that we want using the `tweet_fields` and `expansions` (as shown in the examples above).
# - Python code example:
#
# ```python
# client = tweepy.Client(bearer_token='REPLACE_ME')
#
# # Replace user ID
# id = '2244994945'
#
# tweets = client.get_users_mentions(id=id, tweet_fields=['context_annotations','created_at','geo'])
#
# for tweet in tweets.data:
#     print(tweet)
# ```

# %%
client = tweepy.Client(bearer_token=bearer_token)

id = '2244994945'

tweets = client.get_users_mentions(id=id, tweet_fields=['context_annotations','created_at','geo'])

for tweet in tweets.data:
    print(tweet)
# Out:
# TWITTER IGNORES HATE, RACISM, DEATH THREATS‼️
# @TwitterSafety @Policy @TwitterSupport @Twitter @TwitterComms @TwitterAPI @TwitterTogether @TwitterData @TwitterMedia @TwitterDev  @jack @kayvz @vijaya @paraga @derella @boo @leslieberland @dantley @michaelmontano @nedsegal @dotMudge https://t.co/Bj7h1WXeMV
# TWITTER IGNORES HATE, RACISM, DEATH THREATS‼️
# @TwitterSafety @Policy @TwitterSupport @Twitter @TwitterComms @TwitterAPI @TwitterTogether @TwitterData @TwitterMedia @TwitterDev  @jack @kayvz @vijaya @paraga @derella @boo @leslieberland @dantley @michaelmontano @nedsegal @dotMudge https://t.co/kBV9K6Z1PJ
# TWITTER IGNORES HATE, RACISM, DEATH THREATS‼️
# @TwitterSafety @Policy @TwitterSupport @Twitter @TwitterComms @TwitterAPI @TwitterTogether @TwitterData @TwitterMedia @TwitterDev  @jack @kayvz @vijaya @paraga @derella @boo @leslieberland @dantley @michaelmontano @nedsegal @dotMudge https://t.co/9fwH62p8K5
# @TwitterDev @EnterNFT
#
# Blockchain music?
# you should see it.
#
# https://t.co/tBPBXRI3D7
# @TwitterDev Are you ready for RED (TAYLOR'S VERSION) next week??????
# @TwitterDev Hai
# Wokół Basila Kerskiego i gdańskiego Europejskiego Centrum Solidarności, któremu szefuje, od lat toczy się spór. Czy jest to konflikt do rozwiązania? https://t.co/7xUHBRWt4K #example # demo przez @twitterdev
# @dinahkankyAkide @Symply_Tacha @jack @Blackbirds @Twitter @verified @TwitterMoments @TwitterData @TwitterDev OK 😂
#
# BONJOUR TACHA
# #SymplyTacha
# @Symply_Tacha
# @floxybabby @Symply_Tacha @jack @Blackbirds @Twitter @verified @TwitterMoments @TwitterData @TwitterDev For u
#
# BONJOUR TACHA
# #SymplyTacha

# %% [markdown]
# ## 12. Getting a user's followers
#
# - In order to get the followers of a user, we can use the `get_users_followers` function and pass it the user ID.
# - If we want additional fields for the User object such as `profile_image_url`, we can specify those using the `user_fields` parameter.
# - Python code example:
#
# ```python
# client = tweepy.Client(bearer_token='REPLACE_ME')
#
# # Replace user ID
# id = '2244994945'
#
# users = client.get_users_followers(id=id, user_fields=['profile_image_url'])
#
# for user in users.data:
#     print(user.id)
# ```

# %%
client = tweepy.Client(bearer_token=bearer_token)

# Replace user ID
id = '2244994945'

users = client.get_users_followers(id=id, user_fields=['profile_image_url'])

for user in users.data:
    print(user.id)
# Out:
# 4257889227
# 2458303371
# 1040762494413955072
# 1001721049
# 1376816885258280962
# 1252936216401625088
# 1405855468774322185
# 1455174964529676289
# 1268203555812446209
# 947692597576736768
# 1321445006419222529
# 885831769622278144
# 1155780167362629634
# 1439497481889275911
# 709701031765024768
# 2900566797
# 1385555149184065542
# 1453150744131952644
# 82147187
# 1420385470177976322
# 1154797876087648256
# 38919224
# 1126916092985692160
# 1372231024172732426
# 1139785025757569024
# 45303386
# 900589850
# 199013221
# 1171720270840762369
# 951678410
# 1908229255
# 562145707
# 1097428450024017921
# 252047658
# 1279651897562054656
# 865059291971153920
# 1925251148
# 1422841234075406336
# 375659392
# 726377040782352384
# 1329103755539779585
# 1125488509219946497
# 1347521039673085954
# 1334786926721728512
# 1369847492
# 920253912669601792
# 1320619052310487040
# 1200796066058096645
# 1142673153430188032
# 3046852525
# 1454113941693599747
# 163473607
# 1409012831597613064
# 1428260303335149570
# 4818978747
# 1390989297302519811
# 1353965864320643072
# 1098425161689100288
# 995711885218529280
# 1363473425986187264
# 799232456
# 1221772478625783809
# 1309391680030650368
# 1099367449273819139
# 1163725788459331584
# 1444869977350164486
# 1357341988530520067
# 809820434518577152
# 1407008280082358278
# 3065140149
# 1248618476962336771
# 300917333
# 2274174306
# 1250323786525626370
# 65554114
# 917437258596306944
# 918609757430218752
# 1386466408414941185
# 1183099480947724288
# 2924141226
# 4914477483
# 1392949101793185793
# 1270241682961895425
# 909714287945486336
# 947539424711020546
# 162447315
# 2944487773
# 1432028816747208705
# 985516178
# 178754311
# 940299406883950592
# 1412964896740810752
# 1538903107
# 1088520530511216640
# 1385412889503272961
# 1211596027364429824
# 778907812810330113
# 1408350430996799491
# 1456514023277543426
# 1245202667162357760

# %% [markdown]
# ## 13. Getting users that a user follows
#
# - In order to get the list of users that a user follows, we can use the `get_users_following` function and pass it the user ID.
# - If we want additional fields for the User object such as `profile_image_url`, we can specify those using the `user_fields` parameter.
# - Python code example:
#
# ```python
# client = tweepy.Client(bearer_token='REPLACE_ME')
#
# # Replace user ID
# id = '2244994945'
#
# users = client.get_users_following(id=id, user_fields=['profile_image_url'])
#
# for user in users.data:
#     print(user.id)
# ```

# %%
client = tweepy.Client(bearer_token=bearer_token)

# Replace user ID
id = '2244994945'

users = client.get_users_following(id=id, user_fields=['profile_image_url'])

for user in users.data:
    print(user.id)
# Out:
# 15772978
# 4839528448
# 25029451
# 1009484430250053632
# 108209516
# 1062359582
# 243665363
# 459860328
# 273830767
# 2240152338
# 1191670412033196032
# 2638518929
# 3007236186
# 838824636158627840
# 2997635012
# 1596449330
# 22178537
# 853388192
# 13130832
# 49936717
# 1171940098687950848
# 137535997
# 15824980
# 61467706
# 211637915
# 1484826829
# 75263523
# 2584784815
# 2990106209
# 2533768586
# 1637021982
# 1280128841550311424
# 2425259995
# 685863
# 952837155818176512
# 248869046
# 104236352
# 1615654896
# 29970507
# 1168345391135371267
# 124005464
# 3921628635
# 31898295
# 2397965574
# 760738503370084352
# 41204968
# 2276100433
# 495741050
# 340611224
# 16981198
# 32416361
# 379455191
# 6453472
# 292670084
# 1700547000
# 3347115521
# 783677076951924739
# 88262421
# 3349202854
# 14184976
# 160348679
# 154236280
# 948097629409263616
# 2469856424
# 866879520359448577
# 490980933
# 1140344288082944000
# 1181081146227970049
# 261034930
# 1565770556
# 1438844202
# 76540643
# 265104070
# 2349201699
# 2776322588
# 712198542
# 49054165
# 3064903881
# 2894082393
# 19081905
# 105224601
# 2308474213
# 1090221700913029123
# 14089924
# 948868526
# 2206101780
# 1140621092006051840
# 252824570
# 326849698
# 37522774
# 277202420
# 1095357061859328000
# 2359333566
# 19489255
# 19536178
# 761569626685833216
# 715071139
# 839668676
# 618029513
# 1934669329

# %% [markdown]
# ## 14. Getting users that like a Tweet
#
# - In order to get the list of users that like a Tweet, we can use the `get_liking_users` function and pass it the Tweet ID.
# - If we want additional fields for the User object such as `profile_image_url`, we can specify those using the `user_fields` parameter.
# - Python code example:
#
# ```python
# client = tweepy.Client(bearer_token='REPLACE_ME')
#
# # Replace Tweet ID
# id = '1441054496931541004'
#
# users = client.get_liking_users(id=id, user_fields=['profile_image_url'])
#
# for user in users.data:
#     print(user)
# ```

# %%
client = tweepy.Client(bearer_token=bearer_token)

# Replace Tweet ID
id = '1441054496931541004'

users = client.get_liking_users(id=id, user_fields=['profile_image_url'])

for user in users.data:
    print(user)
# Out:
# GBlairsville
# BhashuBhaskar66
# thepranaw
# Prescopella
# kayBoat4
# tahsina_
# AtikaIgnatius
# shenmei_
# HillaryMutaiK
# girgingizem_
# nahidofficialbd
# Colemanvollrath
# abogadosliti
# kimsonminhoang
# BestNattpat
# StarrSm16219747
# dewinjaemcityx_
# GOKUBR79557892
# RyleeArmond
# KirstenAlana
# ian_stevan
# levvi_matth
# JMarlonPhD
# McmoneyMoni
# dk80ravi
# ShahwezJanisar
# ginabap
# AlamriBadr1515
# Nurulai00878936
# fpistorio
# AGridchina
# TakasakiCamelot
# cj_apes
# JamesNi04940515
# ositablue1
# boyler
# kennedy798
# mustmasro1528
# whimchic
# turkdevops
# OKaMustMan
# DosiosT
# freudian__slip
# superliane
# SdGurjarNewai
# SapnaDangi5
# thesumitgogia
# Aushiker
# dihelander
# Augkenple
# TheRealMatt
# yaar_vaishnavi
# shaokyi
# emilymccleave
# ANSHUCH42890440
# Kaiping_Chen
# sdatemailfr
# MDCinMT
# 2006legend
# Dante_Licona
# MichelleSlater
# deevirga
# yunusfikriansya
# torpey

# %% [markdown]
# ## 15. Getting users that retweeted a Tweet
#
# - In order to get the list of users that retweeted a Tweet, we can use the `get_retweeters` function and pass it the Tweet ID.
# - If we want additional fields for the User object such as `profile_image_url`, we can specify those using the `user_fields` parameter.
# - Python code example:
#
# ```python
# client = tweepy.Client(bearer_token='REPLACE_ME')
#
# # Replace Tweet ID
# id = '1441054496931541004'
#
# users = client.get_retweeters(id=id, user_fields=['profile_image_url'])
#
# for user in users.data:
#     print(user)
# ```

# %%
client = tweepy.Client(bearer_token=bearer_token)

# Replace Tweet ID
id = '1441054496931541004'

users = client.get_retweeters(id=id, user_fields=['profile_image_url'])

for user in users.data:
    print(user)
# Out:
# abogadosliti
# queencharlene95
# tonyv00
# JMarlonPhD
# McmoneyMoni
# dk80ravi
# AlamriBadr1515
# viskobatz
# sturner
# liviaiusan
# Aushiker
# DiwaPh
# AnweshaKnowles
# Augkenple
# TheRealMatt
# sdatemailfr
# 2006legend
# Dman228
# josephlrice
# lenergeek
# MplusG5
# staherym
# DauphineEnergie
# XY194
# zubabakos
# bakosjen
# CsscUniBo1
# haimvat
# jackgirlfriend2
# andypiper
# Elvossss
# nahidofficialbd

# %% [markdown]
# ## 16. Getting Tweets that a user liked
#
# - In order to get the list of Tweets that a user liked, we can use the `get_liked_tweets` function and pass it the User ID.
# - If we want additional fields for the Tweet object such as `context_annotations`, `created_at` etc. we can specify those using the `tweet_fields` parameter.
# - Python code example:
#
# ```python
# client = tweepy.Client(bearer_token='REPLACE_ME')
#
# # Replace User ID
# id = '2244994945'
#
# tweets = client.get_liked_tweets(id=id, tweet_fields=['context_annotations','created_at','geo'])
#
# for tweet in tweets.data:
#     print(tweet)
# ```

# %%
client = tweepy.Client(bearer_token=bearer_token)

# Replace User ID
id = '2244994945'

tweets = client.get_liked_tweets(id=id, tweet_fields=['context_annotations','created_at','geo'])

for tweet in tweets.data:
    print(tweet)
# Out:
# Have you ever wanted to build a Twitter Bot but have no idea of where to start?
# This meetup will give you all the insights and give you a step to step process of building one.
# RSVP via
# https://t.co/IZbgTaC3Rf
# Working on interesting + impactful projects is such a privilege. Unpack the global conversation about #extremeweather events with some beautiful data visualizations, https://t.co/Esf8igqw2D https://t.co/CEbU4y5DJ2
# @TwitterDev Congrats team! The visualizations are beautiful and the message is impactful.
# There’s a lot I could say about this, but I’ll just say… HOW FREAKING COOL?! https://t.co/wGZj1UsrSG
# take your break today getting lost w/ our data-driven artworks &amp; stories that contextualize all the ways Twitter is used during extreme weather or natural disasters ⛈️produced by our Twitter @OfficialPartner (@Brandwatch @SproutSocial &amp; @nttdata_nazuki ) and  @petabencana https://t.co/QteGPV7wp8
# It's been a privilege working with incredible minds to help launch this campaign. The #ClimateCrisis now impacts every corner of the world, &amp; we'll continue to see severe consequences in our lifetime.
#
# This art gives lets you see how this shapes our conversations on Twitter. https://t.co/spVKja5RYm
# Climate change is shaping weather around the world, fueling an increased number of extreme weather events.
#
# In this data visualization, analyze how the conversation develops on Twitter as #ExtremeWeather events unfold across the globe: https://t.co/cZgAbZaJib https://t.co/4diwYobQxE
# @i_am_daniele If I knew who your direct report was, I’d bombard them with praise for all you’ve done and shared with us over these weeks. What a finale. Thank you. @TwitterDev @TwitterDesign @TwitterAPI @jack
# This has been a labor of love and we're so excited to have a great new way to elevate and celebrate all the wonderful people innovating with the Twitter Developer Platform. https://t.co/rhTAYnW2MP
# This is great! @TwitterDev again showing the way forward for how to make APIs and social media data accessible for researchers https://t.co/l8fd7bpUrg
# Honored to be the first developer to be featured in @TwitterDev's love fest 🥰♥️😍 https://t.co/g8TsPoZsij
# @TwitterDev @suhemparack Hey. Have y'all started to save these? I've missed almost each time when I really wanted to join.
# We're so happy for our Official Partner @Brandwatch and their big news. https://t.co/3DwWBNSq0o https://t.co/bDUGbgPkKO
# Check out this feature on @TwitterDev to learn more about how we're mining social media data to make sense of this evolving #publichealth crisis https://t.co/sIFLXRSvEX.
# I awake from five years of slumber https://t.co/OEPVyAFcfB
# @wongmjane Wish we could tell you more, but I’m only a teapot 👀
# Developer Advocate @KukicAdo will be live on Twitch with @TwitterDev's @suhemparack today at 12pm ET (9am PT/6pm CET).
#
# Learn about the new Twitter Developer Labs and how to get the most out of the new API with MongoDB: https://t.co/YbrbVNJrPe https://t.co/z2GtqvHJMR
# Looking for a remote developer job? I put together this tutorial on how you can build an app that searches for remote developer job listings!
#
# It uses the Twitter Labs API, React, &amp; NodeJS.
#
# Check it out 👇
#
# #twitterapi #remotejob @TwitterDev @TwitterAPI
# https://t.co/AQlJKtXXjn
# Peooople! Guess who got featured by Twitter Dev! 🎉 Please click through, sign up, and reach out with whatever requests and suggestions you have.
#
# Also, thanks so much @i_am_daniele and @lyongreg for all of your help while building this; you're the absolute best.
#
# More to come!💥 https://t.co/yiodeOKNYZ
# I’m super excited to have joined the #DevRel team @TwitterDev focusing on helping the academic research community https://t.co/PvVK5VfYCi
# Roses are red,
# Violets are blue,
# Many researchers study Twitter data,
# And you should too!
# #AcademicValentines #AcademicTwitter #AcademicChatter
# https://t.co/zaG7xAvLXf
# Yesterday #TapIntoTwitterLafia hosted it first Meetup of the year.
# #TapIntoTwitter
# Cc:@lvhcolorado @compston @AureliaSpecker @jack @TwitterDev https://t.co/oPY92ACe43
# Twitter libraries are a great way to use our API. Did you know:
#
# ✨ 100+ libraries support the Twitter API
# ✨ In 25+ programming languages 🐍☕️♦️
#
# Explore our curated list of community built libraries 📚
#
# https://t.co/mgXiWmt9SY
# If you like Autohook and you use Python, you should definitely check out Twitivity. Fantastic job @saadmanrafat_ 🙌 https://t.co/20ivInvHJt
# Not 👏 a 👏 single 👏 line 👏 of 👏 code 👏
#
# Use @TwitterDev Labs and iOS Shortcuts to translate your latest Tweet and send it to your friends via iMessage https://t.co/VRtWayHDVl
# 📣 Calling all developers! We're building an API for the Hide Reply feature. We think there’s a lot of potential for sophisticated tools that give people powerful ways of controlling their conversations on Twitter. https://t.co/3t7I7VMEsI
# We were lucky to have @Dr_Black speak last night @TwitterDev #TapIntoTwitter event in London. Aside from her amazing story she is also an ace at selfies. Please share your #selfieswithSue https://t.co/cN6J69rQD4
# Getting ready for tonight’s #TapintoTwitter London event with @Dr_Black @AureliaSpecker https://t.co/TG1Axbkj5p
# Followed by our very own @AureliaSpecker! https://t.co/zSzrardaat
# It's all happening on Tuesday April 30th in NYC! Join us if you're at @SocialMediaWeek for a great panel on tomorrow's social customer experience, with @Racker121 &amp; @mansiped. @salesforce @Rackspace @TwitterDev    https://t.co/yV49ovsgEe
# A shout out to my colleague, @AureliaSpecker, who challenged herself to learn how to code, and in doing so is building her career. #InternationalWomensDay @TwitterDev https://t.co/QPgPXEkN7H
# Special thanks goes to the lecturers @haimvat @karineb @yuvadm @noamr  for taking the time to share your knowledge and insights with our community, the audience was super intrigued and I'm sure they gained a lot, thank you :) https://t.co/Jlc7gL7015
# Huge thanks goes to the awesome team at @TwitterDev @lvhcolorado @andypiper and the entire #TapIntoTwitter team for all the efforts in making this event and the ongoing support of the @tdc_israel community! 🙏🙏🙏
# .@TwitterDev @AndyPiper demystifying #Twemojis 👨🏼‍💻📱 #TapIntoTwitter #TapIntoTwitterNYC https://t.co/Orr6s5KYBO https://t.co/fp9ZWiTpQY
# @TwitterNYC meetup learning about the @TwitterAPI  #TapIntoTwitterNYC #webdevelopment #Developer #code #CodeNewbies #womenintech https://t.co/1fXdrjTsBS
# Listening to @bbokal discuss the power of @TwitterDev data in business applications. #MicrosoftSocialEngagement #MSBizAppsSummit https://t.co/v0jaEKmCnA
# #100DaysOfCode
# Thank you thank you thank you @sunnat629 for this awesome @TwitterDev API guide on how to use the twurl gem.
#
# For those who don't know, this is gem with curl-like functionality for testing Twitter API requests.
#
# https://t.co/y2yidLYknz
# #twitterAPI #ruby #TWURL
# #100DaysOfCode
# Day 7:
# 1️⃣ Learned how to use twurl gem from the @TwitterDev team + @sunnat629
# 2️⃣ Created my create a Twitter list from command line
# 3️⃣ Manage to populate my twitter list from command line
#
# #ruby #learntocode #API
# Thanks @lvhcolorado &amp; the @TwitterAPI @TwitterDev team for the SWAG :) #TapIntoTwitter rules :) 🤟 https://t.co/Lh8M6XnkXL
# Drilling into the 2013 Colorado Flood, by letting geo-tagged Tweets tell the story of how the flood unfolded on Twitter... @TwitterDev @TwitterBoulder https://t.co/npQbEDQG0B
# Yesterday, @TwitterDev asked that apps stop letting users post tweets, likes, and retweets from multiple accounts at a time, for spam prevention. I wanted to make everyone aware that today's beta removes this support from Talon, as per their policy.
#
# https://t.co/VAvMESL6EA
# @TwitterDev  Lafia twitter developer community is holding its maiden event Live. #Tapintotwitter @kellyshalk @lvhcolorado @andypiper https://t.co/DGWk7NWkKl
# @TwitterDev  we re enjoying lafia twitter maiden event, is super cool to be here, #Tapintotwitter https://t.co/CMFrRyFiHg
# @TwitterDev  our lead at lafia twitter developer community, @MAJIDADI_KARAMI  explaining what is twitter developer community. #Tapintotwitter https://t.co/oC5VLnkmpH
# @twitterDev
# #tapintoTwitter
#
# A workshop on @TwitterAPI for @Android on #5Nov
# @TwitterDev @kellyshalk @andypiper
# #TapIntoTwitter #Bangladesh
# https://t.co/9Chub75GrB
# Got a question? Twitter data has an answer. Here are 25 things @Brandwatch learned analyzing billions of Tweets https://t.co/me2Av8FSck
# Inspired by all the smart kiddos today! Great partnering with you @5280mark @googledevs @TwitterDev #techfun #ColoradoDevFest https://t.co/iiLIRU6e9c
# Having a blast at #ColoradoDevFest #9news @TwitterDev @GoogleDevs https://t.co/KWcDoy3jgT
# Helped BVP in this Hackathon. Future of India is bright. Met 100 highly motivated college students trying to build innovative apps https://t.co/DQnHm0BpCu
# Revisiting my camera roll and remembering how young @romainhuet was and how big his hair was 👶 ❤️ #tbt https://t.co/GDOeXRPUwL
# @TwitterDev Hello, someone could check this please ? https://t.co/vdItswTuIg
# Thank you !

# %% [markdown]
# ## 17. Lookup Tweets using Tweet IDs
#
# - In some cases, if we have a list of Tweet IDs and want to build the Tweet dataset for these Tweet IDs, we can use the `get_tweets` function and pass it the list of Tweet IDs.
# - By default, only the Tweet ID and Tweet text are returned. If we want additional Tweet fields, we can specify those using `tweet_fields` parameter.
# - Python code example:
#
# ```python
# client = tweepy.Client(bearer_token='REPLACE_ME')
#
# # Replace Tweet IDs
# ids = ['1409935014725177344', '1409931481552543749', '1441054496931541004']
#
# tweets = client.get_tweets(ids=ids, tweet_fields=['context_annotations','created_at','geo'])
#
# for tweet in tweets.data:
#     print(tweet)
# ```

# %%
client = tweepy.Client(bearer_token=bearer_token)

# Replace Tweet IDs
ids = ['1409935014725177344', '1409931481552543749', '1441054496931541004']

tweets = client.get_tweets(ids=ids, tweet_fields=['context_annotations','created_at','geo'])

for tweet in tweets.data:
    print(tweet)
# Out:
# Super excited to share our course on Getting started with the #TwitterAPI v2 for academic research
#
# If you know students who might be interested in learning how to get started with the #TwitterAPI for research or know professors who can use this in their classes pls RT &amp; share 🙏 https://t.co/kbDnRNU0mj
# Students &amp; researchers, we have something new for you. 🌟
#
# Introducing a new 101 course designed to help you start with academic research using the #TwitterAPI v2. 📖
#
# Complete with cheat sheets and code samples in Python and R, so you can plug and play. https://t.co/ugh9Md6ADN https://t.co/FaZN1Y8WwJ
# Climate change is shaping weather around the world, fueling an increased number of unusual and extreme weather events.
#
# In this data visualization, analyze what happens on Twitter as #ExtremeWeather unfolds across the globe: https://t.co/ult5vZ3wwQ https://t.co/KjmGmVsQEx

# %% [markdown]
# ## 18. Lookup Users using User IDs
#
# - In some cases, if we have a list of User IDs and want to build the User dataset for these User IDs, we can use the `get_users` function and pass it the list of User IDs.
# - If we want additional User fields, we can specify those using `user_fields` parameter.
# - Python code example:
#
# ```python
# client = tweepy.Client(bearer_token='REPLACE_ME')
#
# # Replace User IDs
# ids = ['2244994945']
#
# users = client.get_users(ids=ids, user_fields=['profile_image_url'])
#
# for user in users.data:
#     print(user.profile_image_url)
# ```

# %%
client = tweepy.Client(bearer_token=bearer_token)

# Replace User IDs
ids = ['2244994945']

users = client.get_users(ids=ids, user_fields=['profile_image_url'])

for user in users.data:
    print(user.profile_image_url)
# Out:
# https://pbs.twimg.com/profile_images/1445764922474827784/W2zEPN7U_normal.jpg
